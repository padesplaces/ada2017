# %% [markdown]
# # PROJECT - *My Way* of seeing music covers
# #### Pierre-Antoine Desplaces, Anaïs Ladoy, Lou Richard

# %%
# Import libraries
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from io import StringIO
import sys

# %% [markdown]
# ## Data organisation
# - All the additional files were downloaded from the cluster giving all the metadata of the Million Songs dataset. They will help to elaborate a plan and a script will then search more information about a specific track (h5 files in the cluster) maybe using cluster cpu. The path to access to a track in the cluster is for example million-songs/data/A/A/A (with the 3 letters at the end being the 3rd, 4th and 5th letter on the track id).
# - The music covers will be detected using another dataset (SecondHandSongs), we have the choice to use the downloadable dataset containing 18,196 tracks (all with a connection to the MSD dataset), or to web-scrapp the SHS website (https://secondhandsongs.com/) where we have much more information (522 436 covers) but not necessarly connected to our MSD dataset. The SHS API is RESTful (return a JSON object) and we are limited to 100 requests per minute and 1000 requestion per hour but we can contact them to remove limitation.
# - Some artist are geolocalised (30% of the MSD total artists) on the artist_location dataframe.

# %%
#Load Additional files
tracks_per_year=pd.read_csv('data/AdditionalFiles/tracks_per_year.txt',delimiter='<SEP>',engine='python',header=None,index_col=1,names=['year','trackID','artist','title'])
unique_tracks=pd.read_csv('data/AdditionalFiles/unique_tracks.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['trackID','songID','artist','title'])
unique_artists=pd.read_csv('data/AdditionalFiles/unique_artists.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['artistID','artistMID','randomTrack','name'])
artist_location=pd.read_csv('data/AdditionalFiles/artist_location.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['artistID','lat','long','name','location'])

# %%
#Check if indexes is unique and print the number of elements for each dataframe
print('Dataframe (Unique index, Number of elements)')
print('tracks_per_year ',(tracks_per_year.index.is_unique,tracks_per_year.shape[0]))
print('unique_tracks ',(unique_tracks.index.is_unique,unique_tracks.shape[0]))
print('unique_artists ',(unique_artists.index.is_unique,unique_artists.shape[0]))
print('artist_location ',(artist_location.index.is_unique,artist_location.shape[0]))
# Out:
# Dataframe (Unique index, Number of elements)
# tracks_per_year  (True, 515576)
# unique_tracks  (True, 1000000)
# unique_artists  (True, 44745)
# artist_location  (True, 13850)

# %%
tracks_per_year.head()
# Out:
#                     year           artist                title
# trackID
# TRSGHLU128F421DF83  1922   Alberta Hunter         Don't Pan Me
# TRMYDFV128F42511FC  1922  Barrington Levy   Warm And Sunny Day
# TRRAHXQ128F42511FF  1922  Barrington Levy      Looking My Love
# TRFAFTK12903CC77B8  1922  Barrington Levy   Warm And Sunny Day
# TRSTBUY128F4251203  1922  Barrington Levy  Mandela You're Free

# %%
unique_tracks.head()
# Out:
#                                 songID            artist              title
# trackID
# TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
unique_tracks.artist.unique().shape
# Out:
# (72665,)

# %%
unique_artists.head()
# Out:
#                                                artistMID         randomTrack  \
# artistID
# AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  TRMUOZE12903CDF721
# AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672  TRWDPFR128F93594A6
# AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65  TRMZLJF128F4269EAC
# AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476  TRMGURO12903CAE2F0
# AR009SZ1187B9A73F4  8cd574c0-b9f7-4998-94f4-654dffaecdf2  TRGWWFP12903CE7E79
#
#                                                                  name
# artistID
# AR002UA1187B9A637D                                       The Bristols
# AR003FB1187B994355                                           The Feds
# AR006821187FB5192B  Stephen Varcoe/Choir of King's College_ Cambri...
# AR009211187B989185                                   Carroll Thompson
# AR009SZ1187B9A73F4                                          Gorodisch

# %%
unique_artists.head()
# Out:
#                                                artistMID         randomTrack  \
# artistID
# AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  TRMUOZE12903CDF721
# AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672  TRWDPFR128F93594A6
# AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65  TRMZLJF128F4269EAC
# AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476  TRMGURO12903CAE2F0
# AR009SZ1187B9A73F4  8cd574c0-b9f7-4998-94f4-654dffaecdf2  TRGWWFP12903CE7E79
#
#                                                                  name
# artistID
# AR002UA1187B9A637D                                       The Bristols
# AR003FB1187B994355                                           The Feds
# AR006821187FB5192B  Stephen Varcoe/Choir of King's College_ Cambri...
# AR009211187B989185                                   Carroll Thompson
# AR009SZ1187B9A73F4                                          Gorodisch

# %%
artist_location.head()
# Out:
#                          lat      long                  name  \
# artistID
# ARZGXZG1187B9B56B6 -16.96595 -61.14804          Endless Blue
# AR8K6F31187B99C2BC  46.44231 -93.36586               Go Fish
# ARHJJ771187FB5B581  51.59678  -0.33556  Screaming Lord Sutch
# ARJ8YLL1187FB3CA93  40.69626 -73.83301          Morton Gould
# ARYBAGV11ECC836DAC  43.58828 -79.64372        Crash Parallel
#
#                                       location
# artistID
# ARZGXZG1187B9B56B6                  Santa Cruz
# AR8K6F31187B99C2BC             Twin Cities, MN
# ARHJJ771187FB5B581  Harrow, Middlesex, England
# ARJ8YLL1187FB3CA93           Richmond Hill, NY
# ARYBAGV11ECC836DAC                 Mississauga

# %%
def read_shs_files(pathToFile):
    f = open(pathToFile)
    s = StringIO()
    cur_ID = None
    for ln in f:
        if not ln.strip():
                continue
        if ln.startswith('%'):
                cur_ID = ln.replace('\n','<SEP>',1)
                continue
        if cur_ID is None:
                print ('NO ID found')
                sys.exit(1)
        s.write(cur_ID + ln)
    s.seek(0)
    df = pd.read_csv(s,delimiter='<SEP>',engine='python',header=None,names=['shsID','trackID','artistID','shsPerf'])
    return df

# %%
data=read_shs_files('data/SHS_testset.txt')

# %%
data.shsID=data.shsID.str.strip('%')
#data = data.set_index(['shsID'], inplace=True)

# %%
data
# Out:
#                                                   shsID             trackID  \
# 0                   115402,74782, Putty (In Your Hands)  TRJVDMI128F4281B99
# 1                   115402,74782, Putty (In Your Hands)  TRNJXCO128F92E1930
# 2                         24350, I.G.Y. (Album Version)  TRIBOIS128F9340B19
# 3                         24350, I.G.Y. (Album Version)  TRGXZDU128F9301E53
# 4                   79178, When The Catfish Is In Bloom  TRQSIOY128F92FACA7
# 5                   79178, When The Catfish Is In Bloom  TRXEFPP128F92F9D97
# 6                             11012, Sheer Heart Attack  TRXIXMS128F4287B96
# 7                             11012, Sheer Heart Attack  TRABVTG128F934AB80
# 8                             11012, Sheer Heart Attack  TRRZZZZ128F422F784
# 9                                5262, Calling Dr. Love  TRNBZMV128F42B261C
# 10                               5262, Calling Dr. Love  TRZFOYF128F148D281
# 11                    10974, Standing At The Crossroads  TRNTRUC128F4234EB5
# 12                    10974, Standing At The Crossroads  TRFACVP128F931DF8E
# 13                    10974, Standing At The Crossroads  TRGJNCX128F1456B59
# 14                    10974, Standing At The Crossroads  TRLGBDK128F9314B44
# 15                    10974, Standing At The Crossroads  TRETOLL128F4266338
# 16                    10974, Standing At The Crossroads  TROKQBW128F92FACDF
# 17                    10974, Standing At The Crossroads  TRKGFVN128F4250F29
# 18                    10974, Standing At The Crossroads  TRVJQRV128F4214321
# 19                    10974, Standing At The Crossroads  TRTGOUT128F92F9590
# 20                              42790, The Hustle Is On  TRTRMDB128F4267363
# 21                              42790, The Hustle Is On  TRGYGGS12903CF2C06
# 22                               5334, Come On Let's Go  TRXOKXC12903CB3123
# 23                               5334, Come On Let's Go  TRZIROW128F426BFD7
# 24                               5334, Come On Let's Go  TRCSHVP12903CDBB13
# 25                               5334, Come On Let's Go  TRQGRYX12903CB3414
# 26    932,1405,918, If You Go Away (1999 Digital Rem...  TRIPLSI128F1460659
# 27    932,1405,918, If You Go Away (1999 Digital Rem...  TRWBQZQ12903CF7339
# 28    932,1405,918, If You Go Away (1999 Digital Rem...  TRCTHMX128F932731A
# 29    932,1405,918, If You Go Away (1999 Digital Rem...  TRHFJMC128F935374B
# ...                                                 ...                 ...
# 5206                                 -47, summer of '69  TRVYXGT128F1453DD4
# 5207                                 -47, summer of '69  TREUEAZ128F1456D2B
# 5208                                       -46, suzie q  TRRQOVR128F1467436
# 5209                                       -46, suzie q  TRAHRMW128F1457351
# 5210                          -44, the tears of a clown  TRSQZWC128F92D2D52
# 5211                          -44, the tears of a clown  TRBNCKF128E0792D8D
# 5212                       -39, the kids aren't alright  TRXIBFG128F42A4CFF
# 5213                       -39, the kids aren't alright  TROULLP12903CB02F9
# 5214                      -33, there i've said it again  TRJFVHU128F932D92D
# 5215                      -33, there i've said it again  TREOXAD128F42AEE43
# 5216                 -32, this ain't the summer of love  TRVKLXX128F426FB60
# 5217                 -32, this ain't the summer of love  TRSQFDB128F934B0A7
# 5218            -25, what becomes of the broken hearted  TRSQUUA12903CBCC03
# 5219            -25, what becomes of the broken hearted  TRJSQIB128E0795400
# 5220              -24, what have you done for me lately  TRCEVWQ128EF35E203
# 5221              -24, what have you done for me lately  TRBADDK128F4263C9C
# 5222                         -22, where did our love go  TRWTCMH128E078496D
# 5223                         -22, where did our love go  TRUXBQR128EF349A44
# 5224                                 -19, the wild boys  TRBMXZW128E0794B3E
# 5225                                 -19, the wild boys  TRXFNRU128F424C3D3
# 5226                                      -18, wipe out  TRQCEZS12903C9F66F
# 5227                                      -18, wipe out  TREKNGV128F14808AC
# 5228                                      -18, wipe out  TRKAOSA128F422FC95
# 5229                                      -18, wipe out  TRUBFGZ128F933FF05
# 5230                      -15, working in the coal mine  TRPEAEG128F1458AAB
# 5231                      -15, working in the coal mine  TRIHVRA128F92D2D01
# 5232                     -9, you ain't seen nothing yet  TRFGCMV128F426E7DD
# 5233                     -9, you ain't seen nothing yet  TRHFXJW128F429F21A
# 5234                -3, you've got another thing comin'  TRPTPKD128F426A91D
# 5235                -3, you've got another thing comin'  TREPBRV128F424A36B
#
#                 artistID  shsPerf
# 0     AR46LG01187B98DB5D    74784
# 1     ARQD13K1187B98E441   138584
# 2     ARUVZYG1187B9B2809    24350
# 3     AR4LE591187FB3FCFB    24363
# 4     ARU75JD1187FB38B79    79178
# 5     ARZDN5A1187B99338B    79186
# 6     ARL4TII1187B9B46E1    11012
# 7     AR9BVRM1187FB51139    97131
# 8     ARNFBNR1187B9A25C2       -1
# 9     ARGCVZG1187B9B916F    26300
# 10    ARMI8BW1187FB57B2E     5262
# 11    AR49MOS1187B991A8B   139493
# 12    ARXKMZJ11F4C83DF37   101217
# 13    ARCOBLE1187B9A2446    32310
# 14    ARZENOX1187B98A645   141237
# 15    ARKJHKX1187FB5AEE5    17039
# 16    AR5U94U1187FB5CDCF    16206
# 17    ARH1XAK1187B98F188    38920
# 18    ARZHSES1187FB58AAC    10975
# 19    ARQ8BBK1187FB49C9A    90772
# 20    ARGRDHI1187B9B93F0    99698
# 21    AR8Q4RZ1187FB46BDC    42790
# 22    AR8FGM11187FB46DA5    79336
# 23    AR2GJ6Q1187FB570F0    36104
# 24    ARXRPXX1187B9B7251     5335
# 25    AR9GY5W1187B9AEB2B       -1
# 26    ARW5XFX1187B9AE42A   104432
# 27    ARH25101187B99D4A9    69709
# 28    AR6EAZK1187B98E869    84743
# 29    ARZ2UQS1187FB4D297    51618
# ...                  ...      ...
# 5206  ARRJES71187FB4D09E       -1
# 5207  ARBOG0H1187B99F775       -1
# 5208  ARVLMSG1187B98E07E       -1
# 5209  ARSK10P1187B9B717C       -1
# 5210  ARRIYOM1187FB574F5       -1
# 5211  ARV03D41187FB413E8       -1
# 5212  ARP28RX1187B9AF6C4       -1
# 5213  ARWLV931187B9B0F5A       -1
# 5214  ARW7TAR1187B98BB04       -1
# 5215  ARVTPMZ1187FB44AEB       -1
# 5216  AROZ8ZW1187B989A67       -1
# 5217  AR8FMEN1187FB4A657       -1
# 5218  ARRU6BI1187FB5129D       -1
# 5219  ARB7BE11187B9B64E9       -1
# 5220  ART4QZC1187FB51612       -1
# 5221  ARYH89E1187FB53AEA       -1
# 5222  AR5US1D1187B9AEB1F       -1
# 5223  ARJEHDD1187B9B3516       -1
# 5224  AR9L6R11187B9AA3F2       -1
# 5225  ARYLUOI1187B9B0E0F       -1
# 5226  AR3UY051187B9A922A       -1
# 5227  ARACI901187FB49EC4       -1
# 5228  AR1G3G71187B98FE83       -1
# 5229  AR8MDYR1187FB3C066       -1
# 5230  ARYML1P1187B9AF39B       -1
# 5231  ARKGX701187B993970       -1
# 5232  ARR4LPU1187FB434A6       -1
# 5233  ARMXJIZ1187FB4D8A0       -1
# 5234  ARC4L071187B9AC2C0       -1
# 5235  ARS8X3W1187FB39D09       -1
#
# [5236 rows x 4 columns]
