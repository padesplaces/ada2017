# %% [markdown]
# # PROJECT - *My Way* of seeing music covers
# #### Pierre-Antoine Desplaces, Anaïs Ladoy, Lou Richard

# %%
# Import libraries
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from io import StringIO
import sys
import requests
from bs4 import BeautifulSoup
import pickle

# %% [markdown]
# ## Data organisation
# - All the additional files were downloaded from the cluster giving all the metadata of the Million Songs dataset. They will help to elaborate a plan and a script will then search more information about a specific track (h5 files in the cluster) maybe using cluster cpu. The path to access to a track in the cluster is for example million-songs/data/A/A/A (with the 3 letters at the end being the 3rd, 4th and 5th letter on the track id).
# - The music covers will be detected using another dataset (SecondHandSongs), we have the choice to use the downloadable dataset containing 18,196 tracks (all with a connection to the MSD dataset), or to web-scrapp the SHS website (https://secondhandsongs.com/) where we have much more information (522 436 covers) but not necessarly connected to our MSD dataset. The SHS API is RESTful (return a JSON object) and we are limited to 100 requests per minute and 1000 requestion per hour but we can contact them to remove limitation.
# - Some artist are geolocalised (30% of the MSD total artists) on the artist_location dataframe.

# %%
#Load Additional files
tracks_per_year=pd.read_csv('data/AdditionalFiles/tracks_per_year.txt',delimiter='<SEP>',engine='python',header=None,index_col=1,names=['year','trackID','artist','title'])
unique_tracks=pd.read_csv('data/AdditionalFiles/unique_tracks.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['trackID','songID','artist','title'])
unique_artists=pd.read_csv('data/AdditionalFiles/unique_artists.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['artistID','artistMID','randomTrack','name'])
artist_location=pd.read_csv('data/AdditionalFiles/artist_location.txt',delimiter='<SEP>',engine='python',header=None,index_col=0,names=['artistID','lat','long','name','location'])

# %%
#Check if indexes is unique and print the number of elements for each dataframe
print('Dataframe (Unique index, Number of elements)')
print('tracks_per_year ',(tracks_per_year.index.is_unique,tracks_per_year.shape[0]))
print('unique_tracks ',(unique_tracks.index.is_unique,unique_tracks.shape[0]))
print('unique_artists ',(unique_artists.index.is_unique,unique_artists.shape[0]))
print('artist_location ',(artist_location.index.is_unique,artist_location.shape[0]))
# Out:
# Dataframe (Unique index, Number of elements)
# tracks_per_year  (True, 515576)
# unique_tracks  (True, 1000000)
# unique_artists  (True, 44745)
# artist_location  (True, 13850)

# %%
tracks_per_year.head()
# Out:
#                     year           artist                title
# trackID
# TRSGHLU128F421DF83  1922   Alberta Hunter         Don't Pan Me
# TRMYDFV128F42511FC  1922  Barrington Levy   Warm And Sunny Day
# TRRAHXQ128F42511FF  1922  Barrington Levy      Looking My Love
# TRFAFTK12903CC77B8  1922  Barrington Levy   Warm And Sunny Day
# TRSTBUY128F4251203  1922  Barrington Levy  Mandela You're Free

# %%
unique_tracks.head()
# Out:
#                                 songID            artist              title
# trackID
# TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
unique_tracks.artist.unique().shape
# Out:
# (72665,)

# %%
unique_artists.head()
# Out:
#                                                artistMID         randomTrack  \
# artistID
# AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  TRMUOZE12903CDF721
# AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672  TRWDPFR128F93594A6
# AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65  TRMZLJF128F4269EAC
# AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476  TRMGURO12903CAE2F0
# AR009SZ1187B9A73F4  8cd574c0-b9f7-4998-94f4-654dffaecdf2  TRGWWFP12903CE7E79
#
#                                                                  name
# artistID
# AR002UA1187B9A637D                                       The Bristols
# AR003FB1187B994355                                           The Feds
# AR006821187FB5192B  Stephen Varcoe/Choir of King's College_ Cambri...
# AR009211187B989185                                   Carroll Thompson
# AR009SZ1187B9A73F4                                          Gorodisch

# %%
unique_artists.head()
# Out:
#                                                artistMID         randomTrack  \
# artistID
# AR002UA1187B9A637D  7752a11c-9d8b-4220-ac44-e4a04cc8471d  TRMUOZE12903CDF721
# AR003FB1187B994355  1dbd2d7b-64c8-46aa-9f47-ff589096d672  TRWDPFR128F93594A6
# AR006821187FB5192B  94fc1228-7032-4fe6-a485-e122e5fbee65  TRMZLJF128F4269EAC
# AR009211187B989185  9dfe78a6-6d91-454e-9b95-9d7722cbc476  TRMGURO12903CAE2F0
# AR009SZ1187B9A73F4  8cd574c0-b9f7-4998-94f4-654dffaecdf2  TRGWWFP12903CE7E79
#
#                                                                  name
# artistID
# AR002UA1187B9A637D                                       The Bristols
# AR003FB1187B994355                                           The Feds
# AR006821187FB5192B  Stephen Varcoe/Choir of King's College_ Cambri...
# AR009211187B989185                                   Carroll Thompson
# AR009SZ1187B9A73F4                                          Gorodisch

# %%
artist_location.head()
# Out:
#                          lat      long                  name  \
# artistID
# ARZGXZG1187B9B56B6 -16.96595 -61.14804          Endless Blue
# AR8K6F31187B99C2BC  46.44231 -93.36586               Go Fish
# ARHJJ771187FB5B581  51.59678  -0.33556  Screaming Lord Sutch
# ARJ8YLL1187FB3CA93  40.69626 -73.83301          Morton Gould
# ARYBAGV11ECC836DAC  43.58828 -79.64372        Crash Parallel
#
#                                       location
# artistID
# ARZGXZG1187B9B56B6                  Santa Cruz
# AR8K6F31187B99C2BC             Twin Cities, MN
# ARHJJ771187FB5B581  Harrow, Middlesex, England
# ARJ8YLL1187FB3CA93           Richmond Hill, NY
# ARYBAGV11ECC836DAC                 Mississauga

# %%
def read_shs_files(pathToFile):
    f = open(pathToFile)
    s = StringIO()
    cur_ID = None
    for ln in f:
        if not ln.strip():
                continue
        if ln.startswith('%'):
                cur_ID = ln.replace('\n','<SEP>',1)
                continue
        if cur_ID is None:
                print ('NO ID found')
                sys.exit(1)
        s.write(cur_ID + ln)
    s.seek(0)
    df = pd.read_csv(s,delimiter='<SEP>',engine='python',header=None,names=['shsID','trackID','artistID','shsPerf'])
    return df

# %%
#Import the two SHS datasets (SHS data splitted in a train and test set to use for ML if wanted)
SHS_testset=read_shs_files('data/SHS_testset.txt')
SHS_trainset=read_shs_files('data/SHS_trainset.txt')
covers=pd.concat([SHS_testset,SHS_trainset])
covers.shape
# Out:
# (18196, 4)

# %%
covers.shsID=covers.shsID.str.strip('%')

# %%
covers.head()
# Out:
#                                  shsID             trackID  \
# 0  115402,74782, Putty (In Your Hands)  TRJVDMI128F4281B99
# 1  115402,74782, Putty (In Your Hands)  TRNJXCO128F92E1930
# 2        24350, I.G.Y. (Album Version)  TRIBOIS128F9340B19
# 3        24350, I.G.Y. (Album Version)  TRGXZDU128F9301E53
# 4  79178, When The Catfish Is In Bloom  TRQSIOY128F92FACA7
#
#              artistID  shsPerf
# 0  AR46LG01187B98DB5D    74784
# 1  ARQD13K1187B98E441   138584
# 2  ARUVZYG1187B9B2809    24350
# 3  AR4LE591187FB3FCFB    24363
# 4  ARU75JD1187FB38B79    79178

# %%
#Convert shsID to clique id (first convert to category and get a code)
covers=covers.assign(clique_id=(covers.shsID.astype('category')).cat.codes)
#Remove the shsID and the shsPerf columns (useless)
covers.drop('shsID',axis=1,inplace=True)
#covers.drop('shsPerf',axis=1,inplace=True)
#Merge with unique_artists dataframe to find the artist name for each track (no taking consideration of featuring since we take only the name of the artist assigned with the track)
covers=covers.merge(unique_artists[['name']],how='left',left_on='artistID',right_index=True)
#Take the clique id we defined as id of the dataframe (not unique index for now)
#covers.set_index('id',inplace=True)
#covers.sort_index(inplace=True)
#Merge with unique_tracks dataframe to find the track name
covers=covers.merge(unique_tracks[['title']],how='left',left_on='trackID',right_index=True)
#Merge with tracks_per_year dataframe to find the year of each track
covers=covers.merge(tracks_per_year[['year']],how='left',left_on='trackID',right_index=True)

# %%
covers.head()
# Out:
#               trackID            artistID  shsPerf  clique_id  \
# 0  TRJVDMI128F4281B99  AR46LG01187B98DB5D    74784       1433
# 1  TRNJXCO128F92E1930  ARQD13K1187B98E441   138584       1433
# 2  TRIBOIS128F9340B19  ARUVZYG1187B9B2809    24350       2543
# 3  TRGXZDU128F9301E53  AR4LE591187FB3FCFB    24363       2543
# 4  TRQSIOY128F92FACA7  ARU75JD1187FB38B79    79178       5240
#
#                  name                            title    year
# 0  The Detroit Cobras            Putty (In Your Hands)  1998.0
# 1       Sylvie Vartan                 Ne Le Déçois Pas  1962.0
# 2        Donald Fagen           I.G.Y. (Album Version)  1982.0
# 3              Take 6  Beautiful World (Album Version)     NaN
# 4          John Fahey     When The Catfish Is In Bloom  1968.0

# %%
print('Number of cliques :', max(covers.index)+1) #Number of cliques (+1 because id starts at 0)
print('Number of unique tracks :', len(covers.trackID.unique())) 
print('Number of unique artists :', len(covers.artistID.unique()))
print('Number of missing trackID :', len(covers[covers.trackID.isnull()]))
print('Number of missing artistID :', len(covers[covers.artistID.isnull()]))
print('Number of missing years :', len(covers[covers.year.isnull()]))
# Out:
# Number of cliques : 12960
# Number of unique tracks : 18196
# Number of unique artists : 5578
# Number of missing trackID : 0
# Number of missing artistID : 0
# Number of missing years : 4796

# %%
covers=covers.sort_values(['clique_id', 'year'], ascending=[True, True]).reset_index()

# %%
covers.tail()
# Out:
#        index             trackID            artistID  shsPerf  clique_id  \
# 18191   9538  TRUZAVE128F426E391  AR3DLBB1187B98F3DF   106651       5852
# 18192   9540  TRDNIRY128F425A5C8  ARDRJSP126E2B3BEF8       -1       5852
# 18193   9539  TRPVDKP128F934956E  ARELPXQ1187FB384FD   138704       5852
# 18194   5668  TREMVLC128F92EFA95  ARBFDJW1187B9AD27A    29576       5853
# 18195   5667  TRMTMWV128F92F6F78  ARDYR3C1187FB461CE     9986       5853
#
#                                       name         title    year
# 18191                 The Statler Brothers  Oh Happy Day  1993.0
# 18192                        Spiritualized  Oh Happy Day  1998.0
# 18193                        Queen Latifah  Oh Happy Day     NaN
# 18194            The Fabulous Thunderbirds     Tip On In  1987.0
# 18195  George Thorogood And The Destroyers     Tip On In     NaN

# %%
covers[(covers.year.isnull()) & (covers.shsPerf <0)]
# Out:
#        index             trackID            artistID  shsPerf  clique_id  \
# 3      11504  TRKOINL128F42926C3  ARQ5FSZ1187B98AD74       -1          0
# 5      12946  TRYQEDQ128F427917C  ARS4KT21187B9B9438       -1          1
# 13     12813  TRLLCAL128F428B903  ARP2RHS1187B991595       -1          5
# 14     12810  TREVWUZ128F4263A9B  AR9UYPT1187B9AE833       -1          6
# 15     12811  TRGYREY128E0791913  ARQ294N1187FB53D2A       -1          6
# 22     12805  TRQPBQV128F423C1E9  AREH7LP1187B9B7164       -1          9
# 23     12801  TRVXQXV128F427863A  ARTO3L81187B9ACA8C       -1         10
# 24     12802  TRZJWSX12903CA89C1  ARC1IHZ1187FB4E920       -1         10
# 26      5158  TRFWVIP128EF3444F3  ARE66XI1187B9B8743       -1         11
# 30     12799  TRJLBUB128F92E293E  ARN3SEQ1187FB47AA8       -1         13
# 32      5156  TRONGVZ128F9339880  AR69FR01187FB4D250       -1         14
# 38      5152  TRQNMMM128F934AC2A  ARGLOU61187FB55A07       -1         17
# 40      5151  TRVXEHW128F92E271C  ARPC1IG1187B9B2875       -1         18
# 44     12794  TRQSJPX128F930DEF2  AR8QH711187B98FD00       -1         20
# 45     12790  TRXMDOP12903CBC46A  ARKG7TE1187B9A45D8       -1         21
# 46     12791  TRKEXQZ128F14959B0  ARJFOC01187FB413A5       -1         21
# 47     12792  TRRYIVT128F9336500  AR5HOKG1187FB3873E       -1         21
# 51     12943  TRDODTH128F4260511  ARRNHRM1187FB4F1CF       -1         23
# 52     12786  TRDIRXL128F4222742  ARG81VK1187FB401BF       -1         24
# 53     12787  TRJZZNO128F92F48DE  ARXFMP01187FB40768       -1         24
# 55      5149  TROFEEX128F92F190C  AR5JUO91187FB4E90B       -1         25
# 61     12780  TRWCCJK128F428A0E2  ARMVG6A1187B98A963       -1         28
# 65      5145  TRXCPPR128F933D42D  AR7DNHO1187B992B0B       -1         29
# 68      5142  TREMEER128F930D6FE  AR5FP401187FB523C9       -1         31
# 69      5143  TRKJEPZ12903D03D29  ARTEABC1187B9AE16E       -1         31
# 70      5140  TRAUCWW128F933F0C2  ART62KF1187B991525       -1         32
# 71      5141  TREZRCE12903CF8E26  ARR3WHL1187B994331       -1         32
# 75     12940  TRHXZRK12903D02C2D  ARH861H1187B9B799E       -1         34
# 77      5137  TRRFVJY128EF3523EC  AR8OVZ01187B9A5E1A       -1         35
# 78      5134  TRQPOAN128F92E4C62  ARAXIQY1187B9AD8E0       -1         36
# ...      ...                 ...                 ...      ...        ...
# 14718   6300  TRXKHHM128F935928E  AR71RV81187B9A3A46       -1       4695
# 14744    935  TRSMXBI128F931C670  AR4DPD21187B9B821F       -1       4703
# 14769   5846  TRJNAZC128F14567C7  ARBEBBY1187B9B43DB       -1       4710
# 15021   8761  TRCOTNI128F9300227  ARQFPFK1187FB533E1       -1       4800
# 15437   4554  TRRNGQJ128E0794466  ARZ9Q5Q1187B99F085       -1       4928
# 15537   5234  TRQWOUI12903CB102A  AR0K7931187FB4BD84       -1       4964
# 15601   6519  TRBDTEG128F4265CC9  AR5M4GN1187FB3F2F6       -1       4989
# 15620  10854  TRXBFHZ12903CE6F7B  AR6PQT81187FB3F3B2       -1       4996
# 16045   6512  TRAENGN128F426685B  ARJDHQE11F4C83D7DE       -1       5137
# 16118   7356  TRAMFFW128F4263AD7  ARSF0K11187B9AF319       -1       5160
# 16140   6879  TRZRWZE128F9321519  ARO48XX1187B98FC5C       -1       5169
# 16315   2412  TRZZXGK128F42B15D4  ARJDHQE11F4C83D7DE       -1       5227
# 16316   2414  TRPGSAB128F92FF97B  ARWMGMR11F4C83B673       -1       5227
# 16339   1102  TRKGVDE128F42AE630  ARG5N201187FB570F1       -1       5235
# 16442   3560  TRQZYOM128F426EF11  AR5FP401187FB523C9       -1       5264
# 16943   2887  TRKTKSD128F4292507  AR7A8Y61187B998C7A       -1       5443
# 17005   4712  TRVXLUU12903CEBEE1  ARH861H1187B9B799E       -1       5463
# 17066   3910  TRRWBPL12903CC810C  ARLE3PW1187FB3D799       -1       5484
# 17142   5742  TRUFSYB128F4218857  ARBUHDB1187FB3E72C       -1       5513
# 17143   5743  TRSLVSK128F14A5767  ARRVGAX1187FB4D745       -1       5513
# 17144   5746  TRZCYFH128F934F52D  ARELZ6E1187B9B67A4       -1       5513
# 17145   5750  TROALJO128F42888D6  ARIUOLE11F4C83C703       -1       5513
# 17260   3934  TRGNLHM12903CB7C49  ARRSCF51187B98AB1B       -1       5548
# 17288   6934  TRNMHFQ128F934F7A2  AREZMPH11F4C83B364       -1       5553
# 17292   9557  TRGGREX128F147785D  ARO4BQ61187B9B6F3C       -1       5554
# 17297   9919  TRKTWXX12903CDED33  ARRAGCW1187FB4D892       -1       5556
# 17502   8995  TRZVNPV128F93661D0  AR2F8G61187B9A5812       -1       5624
# 17676   4536  TRQGJDR12903CD9A10  AR9L6R11187B9AA3F2       -1       5677
# 18136   2924  TRPMDDK12903D0D320  AREWAAS1187B98C490       -1       5830
# 18189   4112  TRMQPSQ128F426C548  ARAWPR61187B9B5A4C       -1       5851
#
#                                                  name  \
# 3                Connee Boswell & Sy Oliver Orchestra
# 5                                           Fito Paez
# 13                                      Zen Guerrilla
# 14                                           Hear'Say
# 15                              The Mamas & The Papas
# 22                                                War
# 23                                       Jeff Buckley
# 24                                       Jamie Cullum
# 26                                      Ian McCulloch
# 30                                              Heart
# 32                                        The Clovers
# 38                                        Bob Sinclar
# 40                                                Yes
# 44                                  Poi Dog Pondering
# 45                                   Dinah Washington
# 46                                  Delbert McClinton
# 47                                    Shakin' Stevens
# 51                                            Baccara
# 52                                          Mike Ness
# 53                                       Carl Perkins
# 55                                       Ramsey Lewis
# 61                                     Phyllis Nelson
# 65                                        Alton Ellis
# 68                                          Bob Dylan
# 69                                         Blue Cheer
# 70                  Louis Jordan and his Tympany Five
# 71                                       Buster Brown
# 75                                        Johnny Cash
# 77                                      The Dirtbombs
# 78                                      Transatlantic
# ...                                               ...
# 14718                                     The Turtles
# 14744                                        Bob Weir
# 14769  Tom Petty And The Heartbreakers / Stevie Nicks
# 15021                                   Roger McGuinn
# 15437                                       Ian Brown
# 15537                                           Klone
# 15601                                   Bruce Robison
# 15620                                      Don Carlos
# 16045                                       Leadbelly
# 16118                                    James Taylor
# 16140                                  The Pietasters
# 16315                                       Leadbelly
# 16316                                         Weavers
# 16339                            Terence Trent D'Arby
# 16442                                       Bob Dylan
# 16943                                    Ryan Malcolm
# 17005                                     Johnny Cash
# 17066                                 Sticks & Stones
# 17142                                       Bobby Vee
# 17143                                      Little Eva
# 17144                                   Graham Bonnet
# 17145                                   Suzy Thompson
# 17260                                    Beki Bondage
# 17288                                 Everly Brothers
# 17292                                            Jags
# 17297                                          D.O.A.
# 17502                                    Nicki French
# 17676                                     Duran Duran
# 18136                                  Robert Johnson
# 18189                                The Strangeloves
#
#                                                   title  year
# 3                                             Star Dust   NaN
# 5                         Yo Vengo A Ofrecer Mi Corazon   NaN
# 13                                     Moonage Daydream   NaN
# 14                                        Monday Monday   NaN
# 15                                       Monday_ Monday   NaN
# 22                                            Low Rider   NaN
# 23                       Lover_ You Should've Come Over   NaN
# 24                     Lover_ You Should Have Come Over   NaN
# 26                                  Lover_ Lover_ Lover   NaN
# 30                                   Love Reign O'er Me   NaN
# 32                                     Love Potion No 9   NaN
# 38                              Long Live Rock and Roll   NaN
# 40                          THE LONG DISTANCE RUNAROUND   NaN
# 44                         Living With the Dreaming Boy   NaN
# 45                            Lipstick Powder And Paint   NaN
# 46                             Lipstick_ Powder & Paint   NaN
# 47                           Lipstick_ Powder And Paint   NaN
# 51                                Yes Sir_ I Can Boogie   NaN
# 52              Let The Jukebox Keep On Playing (Album)   NaN
# 53                      Let The Jukebox Keep On Playing   NaN
# 55                                           Les Fleurs   NaN
# 61                                 Land Of Make Believe   NaN
# 65                       La La Means I Love You  (live)   NaN
# 68     It Takes A Lot To Laugh_ It Takes A Train To Cry   NaN
# 69     It Takes a Lot to Laugh_ It Takes a Train to Cry   NaN
# 70              Is You Is Or Is You Ain't (Ma' Baby) #2   NaN
# 71                   Is You Is Or Is You Ain't My Baby?   NaN
# 75                             The Wreck of The Old 97   NaN
# 77                                        Insecure_ Me?   NaN
# 78                                In held (' twas) in I   NaN
# ...                                                 ...   ...
# 14718                                   It Aint Me Babe   NaN
# 14744                                          Big Iron   NaN
# 14769                              Something In The Air   NaN
# 15021                             Wasn't Born To Follow   NaN
# 15437                                       Billie Jean   NaN
# 15537                                        Army of Me   NaN
# 15601                                           Trouble   NaN
# 15620                                  River Of Babylon   NaN
# 16045                                     Fannin Street   NaN
# 16118                                          Everyday   NaN
# 16140                                Drinkin and Drivin   NaN
# 16315                                   Goodnight Irene   NaN
# 16316                                   Goodnight Irene   NaN
# 16339                                    Under My Thumb   NaN
# 16442                                    Lay_ Lady_ Lay   NaN
# 16943                             Don't Dream It's Over   NaN
# 17005                             If I Were a Carpender   NaN
# 17066                                     Atlantic City   NaN
# 17142                         Will You Love Me Tomorrow   NaN
# 17143                         Will You Love Me Tomorrow   NaN
# 17144                         Will You Love Me Tomorrow   NaN
# 17145                        Will You Love Me Tomorrow?   NaN
# 17260                                           Rave On   NaN
# 17288                                         Claudette   NaN
# 17292                                Here Comes My Baby   NaN
# 17297                           Taking Care of Business   NaN
# 17502                   Total Eclipse Of the Heart 1994   NaN
# 17676                                     Lady In Black   NaN
# 18136                           Kindhearted Woman Blues   NaN
# 18189                                        Night-Time   NaN
#
# [668 rows x 8 columns]

# %%
print('Number of missing years with valid shsPerf (API request on the performance page) :',len(covers[(covers.year.isnull()) & (covers.shsPerf != -1)]))
print('Number of missing years with invalid shsPerf (API request on the search page to find shsPerf) :',len(covers[(covers.year.isnull())])-len(covers[(covers.year.isnull()) & (covers.shsPerf != -1)]))
# Out:
# Number of missing years with valid shsPerf (API request on the performance page) : 4128
# Number of missing years with invalid shsPerf (API request on the search page to find shsPerf) : 668

# %% [markdown]
# We need to find the missing years in order to rank the cover songs for each clique and thus, find the original song and the following covers. Since year isn't necessarly sufficient informations to discriminate the songs (cover appears sometimes in the same year than the original one), it will be better to have the entire released date for ALL the tracks if the information is available in the SHS website.
#
# Need the shsPerf to access to the song page in SHS website, where we can find informations about the language and the released date of the song. In the dataset, negative values of shsPerf are considered as missing values.
#
# Two ways of doing it :
# - For valid SHS performance ID, access to the performance page (e.g. 'https://secondhandsongs.com/performance/1983') and web-scrapping of the Language and Released date informations using the perfInfo() function.
# - For invalid SHS performance ID, API request to the search page (e.g. 'https://secondhandsongs.com/search/performance?title=blackbird&performer=beatles'), extract the perf ID with the find_PerfID() and then use the perfInfo() function.

# %%
#Compute the order of songs for each clique
#covers['rank']=covers.groupby('clique_id')['year'].rank(method='dense',ascending=True).astype('int')

# %%
#covers.set_index('clique_id',inplace=True)
covers.drop('index',axis=1,inplace=True)

# %%
covers.tail(20)
# Out:
#                   trackID            artistID  shsPerf  clique_id  \
# 18176  TRITRRU128F423DC76  ARJ59K61187FB5B43E    99662       5846
# 18177  TRRCCUQ128F42449F7  ARNUU2R1187B9A316C    99675       5846
# 18178  TRCEMLE128F4281036  ARJ59K61187FB5B43E    99668       5847
# 18179  TRCGGYF128F9338B93  ARYDZKJ1187FB540C6    99680       5847
# 18180  TRAHFYD128F426BBAD  AR94ZOI1187FB46BDA   103980       5848
# 18181  TRRUFPY128F4261744  ARJWDFW1241B9C69AE   118487       5848
# 18182  TRTFWRF128F92E378E  ARX1CYE1187FB3A97B    99730       5849
# 18183  TRBXSHQ128F4278320  ARLM6I41187B9BA123    99731       5849
# 18184  TRGOMBU128F42895B9  AR14CJ91187FB3A994    99733       5849
# 18185  TRMCRMX128F4267AC3  ARSPUHE1187B99DB8A   125607       5850
# 18186  TRNBSWN128F1473B31  ARLG9UJ1187B9B6C67    24567       5850
# 18187  TRWAULS128F1474CBF  AR7GM0K1187B9B74B4    20304       5851
# 18188  TRZVRJL128F92E2984  ARDYR3C1187FB461CE     9982       5851
# 18189  TRMQPSQ128F426C548  ARAWPR61187B9B5A4C       -1       5851
# 18190  TRSDUWY128F92DD39A  ARR176H1187FB4CDFE    99838       5852
# 18191  TRUZAVE128F426E391  AR3DLBB1187B98F3DF   106651       5852
# 18192  TRDNIRY128F425A5C8  ARDRJSP126E2B3BEF8       -1       5852
# 18193  TRPVDKP128F934956E  ARELPXQ1187FB384FD   138704       5852
# 18194  TREMVLC128F92EFA95  ARBFDJW1187B9AD27A    29576       5853
# 18195  TRMTMWV128F92F6F78  ARDYR3C1187FB461CE     9986       5853
#
#                                       name  \
# 18176                         Afghan Whigs
# 18177                 Sounds Like Violence
# 18178                         Afghan Whigs
# 18179                      Marshall_ Susan
# 18180                         Willie Dixon
# 18181             Todd Wolfe Blues Project
# 18182                        Bill Anderson
# 18183                            Roy Clark
# 18184                          Eddy Arnold
# 18185         Frank Marino & Mahogany Rush
# 18186            Charles River Valley Boys
# 18187                    The J. Geils Band
# 18188  George Thorogood And The Destroyers
# 18189                     The Strangeloves
# 18190                Edwin Hawkins Singers
# 18191                 The Statler Brothers
# 18192                        Spiritualized
# 18193                        Queen Latifah
# 18194            The Fabulous Thunderbirds
# 18195  George Thorogood And The Destroyers
#
#                                       title    year
# 18176                         Sammy (Album)  1990.0
# 18177                                 Sammy  2009.0
# 18178                         Going To Town  1996.0
# 18179                         Going To Town  2009.0
# 18180                        The Same Thing  1970.0
# 18181                            Same Thing     NaN
# 18182                 The Tip Of My Fingers  2002.0
# 18183                 The Tip Of My Fingers     NaN
# 18184                 The Tip of My Fingers     NaN
# 18185  Norwegian Wood (This Bird Has Flown)     NaN
# 18186           Norwegian Wood (LP Version)     NaN
# 18187                            Night Time  1980.0
# 18188                            Night Time     NaN
# 18189                            Night-Time     NaN
# 18190                          Oh Happy Day  1969.0
# 18191                          Oh Happy Day  1993.0
# 18192                          Oh Happy Day  1998.0
# 18193                          Oh Happy Day     NaN
# 18194                             Tip On In  1987.0
# 18195                             Tip On In     NaN

# %%
pickle.dump(covers,open('covers.p','wb'))

# %% [markdown]
# To handle :
# - Find the missing years using API request to SHS website (if no informations about the year on the website, find another solution)
# - Find a way to detect the original song if the first cover is the same year? (also the case where two covers are made during the same year and then have the same rank.. problem with multi-index after because not unique)
# - API request to SHS website for the location and the language

# %%
#API request to SHS website for the page of a specific performance (defined as shsPerf) to extract Language and Date
def perfInfo_SHS(shsPerf):
    if shsPerf<0:
        perfLanguage='Unavailable'
        perfDate='Unavailable'
    elif shsPerf>0:
        r = requests.get('https://secondhandsongs.com/performance/'+str(shsPerf))
        print(r.status_code)
        soup = BeautifulSoup(r.text, 'html.parser')
        perfMeta=soup.find_all('dl')[0] 
        perfLanguage=perfMeta.find('dd',attrs={'itemprop':'inLanguage'})
        if perfLanguage is None :
            perfLanguage='Missing'
        else :
            perfLanguage=perfLanguage.text

        perfDate=perfMeta.find('div',attrs={'class':'media-body'})
        if perfDate is None :
            perfDate='Missing'
        else :
            perfDate=perfDate.find('p').text.split('\n')[2].strip(' ')

    return perfLanguage,perfDate

# %%
language=perfInfo_SHS(9986)[0]
date=perfInfo_SHS(9986)[1]
# Out:
# 200
# 200

# %% [markdown]
# Web-scraping - Part of the dataframe each hour (1000 requests by hour)

# %%
#Work with a subset a the dataframe to create the algorithms
part=covers[2055:3017]
part.head()
# Out:
#                  trackID            artistID  shsPerf  clique_id  \
# 2055  TRWJCBY128F4261C0F  AR11YQ81187FB3C654   100068        940
# 2056  TRSSNRG12903CC8518  ARHAL3V1187B9AA462   100066        940
# 2057  TRBWTHA128E0791A0B  ARLAUED1187B9ACEAF    30050        941
# 2058  TRHFTUX128F93010D0  ARB5U6G1187B9A994C    10009        941
# 2059  TRGDJUM12903CC5CD9  ARRHVVL1187B991E41       -1        941
#
#                   name                          title    year
# 2055      Dixie Chicks  Tonight The Heartache's On Me  1998.0
# 2056    Joy Lynn White  Tonight The Heartache's On Me     NaN
# 2057      Eric Clapton       Willie And The Hand Jive  1974.0
# 2058  Johnny Otis Show       Willie And The Hand Jive  1984.0
# 2059       Johnny Otis       Willie And The Hand Jive  1991.0

# %%
print('Number of cliques in the subset :', len(part.clique_id.unique()))
print('Number of tracks in the subset :', part.shape[0])
print('Number of missing years in the subset :', len(part[part.year.isnull()]))
print('Number of invalid shsPerf in the subset :', len(part[part.shsPerf<0]))
# Out:
# Number of cliques in the subset : 298
# Number of tracks in the subset : 962
# Number of missing years in the subset : 269
# Number of invalid shsPerf in the subset : 29

# %%
part['language'], \
part['date'] = zip(*part.shsPerf.map(perfInfo_SHS))

# %%
part.to_csv('data/partSHS_webscraping/part_0_800.csv')

# %%
r = requests.get('https://secondhandsongs.com/performance/30050')
print(r.status_code)
soup = BeautifulSoup(r.text, 'html.parser')
soup.body
# Out:
# 200
# <body class="">
# <div class="loading">
# <div class="loader"></div>
# </div>
# <input name="_ds" type="hidden" value="0"/>
# <section id="header">
# <header class="container">
# <div class="row"> <div class="col-lg-4 col-sm-5 hidden-xs">
# <a class="logo" href="/">
# <img alt="Second Hand Songs - A Cover Songs Database" src="/art/logo.png"/>
# </a>
# </div>
# <nav class="col-lg-8 col-sm-7" id="top-menu" role="navigation">
# <ul class="nav navbar-nav navbar-right" id="top-menu-navbar-collapse">
# <li class="visible-xs"><a class="logo" href="/"><img alt="Second Hand Songs - A Cover Songs Database" src="/art/logo.png"/></a>
# </li>
# <li><a href="/explore">Explore</a></li>
# <li><a href="/forum">Discuss
#                                                     </a></li>
# <li>
# <a href="/participate">Participate
#                                                     </a>
# </li>
# <li>
# <a href="/quiz">Play </a>
# </li>
# <li class="accent"><a href="/login?ref=%2Fperformance%2F30050">Sign
#                                 In</a></li>
# <li class="social">
# <a href="https://www.facebook.com/pages/SecondHandSongs/25077961981" title="Like us on Facebook">
# <i class="fa fa-facebook-square fa-lg "></i>
# </a>
# <a href="https://twitter.com/SHSongs" title="Follow us on twitter">
# <i class="fa fa-twitter-square fa-lg "></i>
# </a>
# <a href="https://plus.google.com/+Secondhandsongs" title="Follow us on Google+">
# <i class="fa fa-google-plus-square fa-lg "></i>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# </section>
# <section id="topsearch">
# <div class="container">
# <form action="/search" class="form-inline row" id="topsearch-form">
# <div class="col-sm-3 hidden-xs">
# <h2 style="text-align:right">Discover</h2>
# </div>
# <div class="col-sm-6 col-xs-9">
# <div class="input-group" style="width: 100%;">
# <input class="form-control" id="topsearch-input" name="search_text" placeholder="Find cover songs, artists and more" type="text" value=""/>
# <div class="input-group-btn">
# <button accesskey="z" class="btn" id="topsearch-button">Go</button>
# </div>
# </div>
# </div>
# <div class="col-sm-3 col-xs-3">
# <p style="padding-top:6px;">
# <a class="section-more" href="/search/work">Detailed search</a>
# <p>
# </p></p></div>
# </form>
# </div>
# </section>
# <section id="alert">
# <section class="alert-danger">
# <div class="container" id="alert-container">
# <div class="errormsg alert" style="display:none;">
# <h4>Error!</h4>
# <p></p>
# <span class="error-data" style="display:none;"></span>
# </div>
# </div>
# </section>
# <section class="alert-warning">
# <div class="container">
# <div class="warning alert" style="display:none;">
# <h4>Warning</h4>
# <p></p>
# <input class="btn btn-default" name="override" type="button" value="Confirm"/>
# <input class="btn btn-default" type="button" value="Cancel"/>
# </div>
# </div>
# </section>
# <section class="alert-success">
# <div class="container">
# <div class="successmsg alert" style="display:none;">
# <p></p>
# </div>
# </div>
# </section>
# </section>
# <section id="main">
# <div itemscope="" itemtype="http://schema.org/MusicRecording">
# <section class="has-tabs" id="content">
# <div class="container">
# <section class="row" id="entity-topbar">
# <div class="col-sm-12">
# </div>
# <div class="col-sm-9">
# <div class="pull-left">
# <h2 class="section-title">Cover</h2>
# </div>
# <aside class="pull-right">
# <div class="btn-toolbar">
# <div class="btn-group">
# <a class="btn btn-default btn btn btn-primary" href="/work/10009/submit-cover" id="add-cover">
# <i class="fa fa-plus fa- "></i>                     Add cover                </a>
# </div>
# <div class="btn-group">
# <a class="btn btn-default btn " href="/report-error?performanceId=30050" id="report-error">
# <i class="fa fa-edit fa- "></i>                     Report error                </a>
# </div>
# </div>
# </aside>
# </div>
# <div class="col-sm-3">
# <aside class="pull-right">
# <div class="addthis-box">
# <!-- AddThis Button BEGIN -->
# <div class="addthis_toolbox addthis_default_style addthis_20x20_style">
# <a class="addthis_button_facebook"></a>
# <a class="addthis_button_twitter"></a>
# <a class="addthis_button_google_plusone_share"></a>
# <a class="addthis_button_compact"></a>
# </div>
# <script type="text/javascript">var addthis_config = { "data_track_addressbar":false };</script>
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=secondhandsongs" type="text/javascript"></script>
# <!-- AddThis Button END -->
# </div>
# </aside>
# </div>
# </section>
# <header class="row">
# <div class="col-sm-12">
# <h1>
# <span itemprop="name"><a class="link-performance" href="/performance/30050">Willie and the Hand Jive</a></span>
# <em>by</em> <span itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup"><a class="link-proxies\__cg__\performer" href="/artist/214" itemprop="url"><span itemprop="name">Eric Clapton</span></a></span></h1>
# </div>
# </header>
# <div class="row" id="entity-info">
# <div class="col-sm-5 col-md-4 col-lg-3" id="entity-visual">
# <div class="perf_video">
# <iframe allowfullscreen="" class="" height="195" mozallowfullscreen="" src="//www.youtube.com/embed/D-qvoa0oNDM?rel=0&amp;version=3&amp;modestbranding=1&amp;loop=1&amp;wmode=opaque&amp;rel=0&amp;controls=2&amp;showinfo=1&amp;" style="border:none;" webkitallowfullscreen="" width="260"></iframe>
# <div>
# <small>
#                     Added by <a class="link-proxies\__cg__\user" href="/user/1387">Limbabwe</a>
# </small>
# <small>
# <span class="btn btn-default btn-xs" title="Youtube videos may not match exact versions."><i class="fa fa-info-circle fa- "></i></span>
# <a class="btn btn-default btn-xs" href="/report-error?performanceId=30050&amp;videoId=D-qvoa0oNDM" title="Wrong video? Click here to report."><i class="fa fa-bolt fa- "></i></a>
# </small>
# </div>
# </div>
# </div>
# <div class="col-sm-7 col-md-8 col-lg-6">
# <dl class="dl-horizontal">
# <dt>Written by</dt>
# <dd><span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a class="link-artist" href="/artist/6808" itemprop="url"><span itemprop="name">Johnny Otis</span></a></span></dd>
# <dt>Language</dt>
# <dd itemprop="inLanguage">English</dd>
# <dt>Released on</dt>
# <dd>
# <div class="media" itemprop="inAlbum" itemscope="" itemtype="http://schema.org/MusicAlbum">
# <a class="pull-left" href="/release/567">
# <img alt="461 Ocean Boulevard" class="media-object" itemprop="image" src="/picture/7833/tiny">
# </img></a>
# <div class="media-body">
# <p><a class="link-release" href="/release/567" itemprop="url"><span itemprop="name">461 Ocean Boulevard</span></a>
# <br/>Album
#                                                                                                     <br/>1974
#                                                             </p>
# </div>
# </div>
# </dd>
# <dt>Rating</dt>
# <dd class="datatext">
# <span data-id="30050" data-score="4" data-type="performance" data-user-rating="0" id="rating"></span>
# <span id="rating-hint"></span>
# </dd>
# <dt>Licensing</dt>
# <dd>
# <a href="/license/request?performance=30050">Request a synchronization license</a>
# <span title="A synchronization license allows you to use the work with some kind of visual media output (film, television shows, advertisements, video games, accompanying website music, movie trailers, etc.).">
# <i class="fa fa-question-circle fa- "></i></span>
# </dd>
# </dl>
# <dl class="dl-horizontal">
# <dt>Buy</dt>
# <dd>
# <div class="affiliate-links">
# <a href="http://www.amazon.com/gp/search/ref=as_li_qf_sp_sr_tl?ie=UTF8&amp;camp=1789&amp;creative=9325&amp;index=aps&amp;linkCode=ur2&amp;tag=secon08-20&amp;linkId=7FSBB5SUNC3DESQ2&amp;keywords=Willie+and+the+Hand+Jive+Eric+Clapton"><img alt="Buy from Amazon" src="/art/amazon.png" title="Buy from Amazon"/></a>
# <img alt="" border="0" height="1" src="https://ir-na.amazon-adsystem.com/e/ir?t=secon08-20&amp;l=ur2&amp;o=1" style="border:none !important; margin:0px !important;" width="1"/>
# </div>
# </dd>
# </dl>
# </div>
# <div class="col-sm-12 col-lg-3">
# <p class="objectstamp clear">
# <small>
#
#         Added by <a class="link-proxies\__cg__\user" href="/user/9">Canary</a>
# </small>
# </p>
# <aside>
# <ins class="adsbygoogle ad-responsive-sidebar" data-ad-client="ca-pub-0911039226894166" data-ad-slot="1304538087" style="display:inline-block"></ins>
# </aside>
# <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
# </div>
# </div>
# </div>
# </section>
# <section id="entity-tabs">
# <div class="container">
# <ul class="nav nav-tabs nav-justified" id="nav-entity">
# <li class="active"><a href="/performance/30050/originals#nav-entity">Originals</a>
# </li>
# <li><a href="/performance/30050/versions#nav-entity">Versions
#                     <span class="label label-default">38</span></a></li>
# <li><a href="/performance/30050/adaptations#nav-entity">Adaptations <span class="label label-default">2</span></a>
# </li>
# <li><a href="/performance/30050/all#nav-entity">All</a>
# </li>
# </ul>
# </div>
# </section>
# <section id="entity-section">
# <div class="container">
# <section class="work-originals">
# <h2 class="section-title" id="t1">Originals</h2>
# <article class="clearfix" itemprop="recordingOf" itemscope="" itemtype="http://schema.org/MusicComposition">
# <h2 class="divider"><a class="link-work" href="/work/10009" itemprop="url"><span itemprop="name">Willie and the Hand Jive</span></a></h2>
# <section class="row">
# <section class="col-sm-3" itemprop="recordedAs" itemscope="" itemtype="http://schema.org/MusicRecording">
# <div class="media">
# <a class="pull-left" href="/artist/6808">
# <img alt="The Johnny Otis Show" src="/picture/150382/tiny"/>
# </a>
# <div class="media-body">
# <p><a href="/performance/10009" itemprop="url"><strong>First release</strong></a>
# <em>by</em> <span itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup"><a class="link-performer" href="/artist/6808" itemprop="url"><span itemprop="name">The Johnny Otis Show</span></a></span>
#                                                                                             (April 1958)
#                                                     </p>
# </div>
# </div>
# <div class="flex-video">
# <iframe allowfullscreen="" class="" height="160" mozallowfullscreen="" src="//www.youtube.com/embed/kIlX4w7Bs3Y?rel=0&amp;version=3&amp;modestbranding=1&amp;loop=1&amp;wmode=opaque&amp;rel=0&amp;controls=2&amp;showinfo=1&amp;" style="border:none;" webkitallowfullscreen="" width="200"></iframe>
# </div>
# </section>
# <section class="col-sm-1"></section>
# </section>
# </article>
# </section>
# </div>
# </section>
# <section>
# <div class="container">
# <div class="col-sm-9">
# <aside class="pull-right">
# <div class="btn-toolbar">
# <div class="btn-group">
# <a class="btn btn-default btn btn btn-primary" href="/work/10009/submit-cover" id="add-cover">
# <i class="fa fa-plus fa- "></i>                     Add cover                </a>
# </div>
# <div class="btn-group">
# <a class="btn btn-default btn " href="/report-error?performanceId=30050" id="report-error">
# <i class="fa fa-edit fa- "></i>                     Report error                </a>
# </div>
# </div>
# </aside>
# </div>
# </div>
# </section>
# <section>
# <div class="container">
# </div>
# </section>
# <section>
# <div class="container">
# <!-- Responsive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-0911039226894166" data-ad-format="auto" data-ad-slot="3198890485" style="display: block;"></ins>
# <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
# </div>
# </section>
# </div>
# </section>
# <footer class="fill" id="footer">
# <div class="container">
# <div class="row">
# <section class="col-sm-3">
# <h2><a href="/"><img alt="SecondHandSongs" class="img-responsive" src="/art/logo-alt-small.png"/></a></h2>
# <p class="lead">Discover <strong>The Original</strong></p>
# <p>SecondHandSongs is building the most comprehensive source of cover song information.</p>
# <p></p>
# <ul class="list-inline">
# <li>
# <a href="mailto:info@secondhandsongs.com" title="Send us an e-mail">
# <i class="fa fa-envelope fa-3x "></i>
# </a>
# </li>
# <li>
# <a href="https://www.facebook.com/pages/SecondHandSongs/25077961981" title="Like us on Facebook">
# <i class="fa fa-facebook-square fa-3x "></i>
# </a>
# </li>
# <li>
# <a href="https://twitter.com/SHSongs" title="Follow us on twitter">
# <i class="fa fa-twitter-square fa-3x "></i>
# </a>
# </li>
# <li>
# <a href="https://plus.google.com/+Secondhandsongs" title="Follow us on Google+">
# <i class="fa fa-google-plus-square fa-3x "></i>
# </a>
# </li>
# </ul>
# </section>
# <section class="col-sm-3">
# <h2>About</h2>
# <ul class="list-unstyled">
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/ContactUs">Contact us</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/Faq">Frequently
#                             asked questions</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/IntroductionToTheDatabase">Introduction
#                             to
#                             the database</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/About">About SecondHandSongs</a>
# </li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/Press">Press releases and
#                             reviews</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/statistics">Database statistics</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/Bookmarks">Bookmarks</a></li>
# </ul>
# <h2>Get involved</h2>
# <ul class="list-unstyled">
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/login">Get an account</a>
# </li> <li><i class="fa fa-angle-double-right fa- "></i> <a href="/board/6">Suggest
#                             covers and samples</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/Main/JoinUs">Join the team</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/wiki/API/Main">Use
#                             our API</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/donate">Make a donation</a></li>
# </ul>
# </section>
# <section class="col-sm-3">
# <h2>Popular performances</h2>
# <ul class="list-unstyled">
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/5851">With You I'm Born Again</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/558683">Havana Song</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/20611">I Think I Love You</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/612400">City of Stars</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/561929">Despacito</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/7255">Only You</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/6392">Take Me Home, Country Roads</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/14673">Last Christmas</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/161">Time After Time</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/performance/6536">Wish You Were Here</a></li>
# </ul>
# </section>
# <section class="col-sm-3">
# <h2>Popular artists</h2>
# <ul class="list-unstyled">
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/70551">2Phat 4Porn</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/8493">Axl Rose</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/3970">Terry Melcher</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/7175">Adriano Celentano</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/112149">Christian Ulvaeus</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/42">Joe Cocker</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/2953">Lemmy</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/100339">Scott &amp; Ryceejo</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/35153">Sue Shifrin</a></li>
# <li><i class="fa fa-angle-double-right fa- "></i> <a href="/artist/504">Guns n' Roses</a></li>
# </ul>
# </section>
# </div>
# <div class="row col-md-12" id="page-closure">
# <ul class="list-inline">
# <li>
# <a href="/wiki/Main/About">© 2003-2017
#                         secondhandsongs.com</a>
# </li>
# <li>
# <a href="/wiki/Main/TermsOfService">Terms of Service</a>
# </li>
# <li>
# <a href="/wiki/Main/PrivacyPolicy">Privacy Policy</a>
# </li>
# </ul>
# </div>
# </div>
# </footer>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="/components/jquery/jquery-built.js"><\/script>')</script>
# <script src="/js/d457f10-e1ce671.js"></script>
# <!--[if lt IE 9]>
#         <script src="/components/Respond/respond.min.js"></script>
#         <script src="http://html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <script src="/js/b2dec0e-8a395d8.js"></script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#         $(document).ready(function() {
#             var hash = window.location.hash;
#             if (hash.indexOf("#_") == 0) {
#                 hash = window.location.hash.substring(2);
#                 var offset = $("a[name=" + hash + "]").offset();
#                 window.scrollTo(offset.left, offset.top-$(window).height()/3);
#             }
#         });
#     </script>
# <script>
#         var _gaq = [
#             ['_setAccount', 'UA-129438-1'],
#             ['_trackPageview']
#         ];
#         _gaq.push(['_setCustomVar', 1, 'Member Type', 'Visitor', 1]);
#         (function (d, t) {
#             var g = d.createElement(t), s = d.getElementsByTagName(t)[0];
#             g.src = ('https:' == location.protocol ? '//ssl' : '//www') + '.google-analytics.com/ga.js';
#             s.parentNode.insertBefore(g, s)
#         }(document, 'script'));
#     </script>
# </body>

# %%
b=soup.find('section',attrs={'class':'work-originals'})

# %%
b
# Out:
# <section class="work-originals">
# <h2 class="section-title" id="t1">Originals</h2>
# <article class="clearfix" itemprop="recordingOf" itemscope="" itemtype="http://schema.org/MusicComposition">
# <h2 class="divider"><a class="link-work" href="/work/10009" itemprop="url"><span itemprop="name">Willie and the Hand Jive</span></a></h2>
# <section class="row">
# <section class="col-sm-3" itemprop="recordedAs" itemscope="" itemtype="http://schema.org/MusicRecording">
# <div class="media">
# <a class="pull-left" href="/artist/6808">
# <img alt="The Johnny Otis Show" src="/picture/150382/tiny"/>
# </a>
# <div class="media-body">
# <p><a href="/performance/10009" itemprop="url"><strong>First release</strong></a>
# <em>by</em> <span itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup"><a class="link-performer" href="/artist/6808" itemprop="url"><span itemprop="name">The Johnny Otis Show</span></a></span>
#                                                                                             (April 1958)
#                                                     </p>
# </div>
# </div>
# <div class="flex-video">
# <iframe allowfullscreen="" class="" height="160" mozallowfullscreen="" src="//www.youtube.com/embed/kIlX4w7Bs3Y?rel=0&amp;version=3&amp;modestbranding=1&amp;loop=1&amp;wmode=opaque&amp;rel=0&amp;controls=2&amp;showinfo=1&amp;" style="border:none;" webkitallowfullscreen="" width="200"></iframe>
# </div>
# </section>
# <section class="col-sm-1"></section>
# </section>
# </article>
# </section>
