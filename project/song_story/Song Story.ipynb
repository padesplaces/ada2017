# %% [markdown]
# # Project story
# ### Follow the evolution of "My way"
#
# #### Plan
# - 14 covers in our dataset and 289 on SHS website
# - Web-scrapping of the covers we don't have
# - Have at least Country/Year/Language/Artist/Title for each song

# %%
# Import libraries
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from io import StringIO
import sys
import requests
from bs4 import BeautifulSoup
import pickle
import os
import glob
from pathlib import Path

# %%
#Load covers dataframe
covers=pickle.load(open("covers_FINAL.p","rb"))

# %%
#Clique of "My way"
covers[covers.title.str.contains('My Way')]
# Out:
#                                         artistID shsPerf  \
# clique_id trackID
# 360       TRIXWWI128F931A549  ARNBQR21187B9B20E1       0
#           TRRDVDU128F9343523  ARHA1XR1187B9B5940       0
# 893       TRLCKQT12903CFC1E8  ARXKJYR1269FB2729B  525079
#           TRXWMEY128F4289BC3  ARFA4301187B9AD04A    6334
#           TRFKFUN128F9327A53  ARJGQ4A1187B99078A       0
# 1190      TRIYKMR12903CC42A5  ARKLWV31187FB4881F  126517
#           TRAGXNT12903CEB1B9  AR7AOEJ1187FB3D279   82005
#           TRBTFYW128F92D4894  ARJIAK51187B9B0C57  114545
#           TRAOJAH12903CF7E6F  ARZH5GY1187B991039  106683
#           TROXIGK128F92C2597  AR4Q56Q1187FB4BF63   51285
#           TRTMLMA12903CCB956  ARM900S1187FB5A3F7  103370
#           TRQDDIF128F933AB89  ARNJ9LU1187B9A56A6  111710
#           TRYEPZK128F42A3425  ARL7YU61187B9B85D7  112544
#           TRDHEGR128F933E76D  ARFAKTH1187B9B0C18   42161
#           TRHDXLP128EF3500FA  ARD3LXU1187B9ABFC5    6467
#           TROJGKW128F9309301  ARV8WE01187FB4D356  149098
#           TRSQJMW128F93135CA  AR2ZLR21187B98D552   82027
#           TROSEGE12903CC292F  ARY5U6T1187FB5AE47   18499
#           TRDOZEB12903CF8B75  AR65T9K1187FB3842E   68888
# 3268      TRCJMWH12903CB0D6A  ARLAUED1187B9ACEAF   63658
#           TRTZPUX128F930F5CB  AR6IHPG1187FB55C49   69193
#           TRXIWCM128F92D2185  AR4PCIG1187B98D07D   80023
# 3651      TRZIQIE128F4271A5C  ARIMH3L1187B9B9178   41685
#           TRAFRJH128E0781C5B  ARZS5VW1187FB567E8  197122
#           TRIJOXI128F9354280  ARHMVQB1187FB3F005   60493
#           TROUXEQ128F428AF38  AR633SY1187B9AC3B9   84324
#           TRXHNET128F4245102  ARW670O1187FB3AC60  123133
# 4905      TRFFLAQ128E0789DA3  AR1WWVL1187B9B0306   69633
#           TRWQTNR128F427B62B  ARYIDC81187B9B326A   69629
# 5728      TRJLNHE128F426D6C3  ARDK0551187FB5AC48    9590
#
#                                                     artist  \
# clique_id trackID
# 360       TRIXWWI128F931A549                   Blodwyn Pig
#           TRRDVDU128F9343523                   The Dickies
# 893       TRLCKQT12903CFC1E8            Calle Kristiansson
#           TRXWMEY128F4289BC3                 Lenny Kravitz
#           TRFKFUN128F9327A53                          Kato
# 1190      TRIYKMR12903CC42A5               Dorothy Squires
#           TRAGXNT12903CEB1B9                 Little Milton
#           TRBTFYW128F92D4894                 Cliff Richard
#           TRAOJAH12903CF7E6F                 Dany Brillant
#           TROXIGK128F92C2597                     Ray Quinn
#           TRTMLMA12903CCB956               Micah P. Hinson
#           TRQDDIF128F933AB89                       Il Divo
#           TRYEPZK128F42A3425    G4 feat. Sir Cliff Richard
#           TRDHEGR128F933E76D     The Chairmen of the Board
#           TRHDXLP128EF3500FA                   Sex Pistols
#           TROJGKW128F9309301                Northern Kings
#           TRSQJMW128F93135CA                Dread Zeppelin
#           TROSEGE12903CC292F                   Los Piratas
#           TRDOZEB12903CF8B75                     Paul Anka
# 3268      TRCJMWH12903CB0D6A                  Eric Clapton
#           TRTZPUX128F930F5CB                         Swans
#           TRXIWCM128F92D2185               Ellen McIlwaine
# 3651      TRZIQIE128F4271A5C          The Psychedelic Furs
#           TRAFRJH128E0781C5B                 William Orbit
#           TRIJOXI128F9354280          The Polyphonic Spree
#           TROUXEQ128F428AF38                        Weezer
#           TRXHNET128F4245102                      Jon Auer
# 4905      TRFFLAQ128E0789DA3                          UB40
#           TRWQTNR128F427B62B  Billy J Kramer & The Dakotas
# 5728      TRJLNHE128F426D6C3          Blind Willie Johnson
#
#                                                                    title  \
# clique_id trackID
# 360       TRIXWWI128F931A549                                  See My Way
#           TRRDVDU128F9343523                                  See My Way
# 893       TRLCKQT12903CFC1E8                     Are You Gonna Go My Way
#           TRXWMEY128F4289BC3                     Are You Gonna Go My Way
#           TRFKFUN128F9327A53                     Are You Gonna Go My Way
# 1190      TRIYKMR12903CC42A5                       My Way (Instrumental)
#           TRAGXNT12903CEB1B9                                      My Way
#           TRBTFYW128F92D4894       My Way (Live) (2008 Digital Remaster)
#           TRAOJAH12903CF7E6F                                      My Way
#           TROXIGK128F92C2597                                      My Way
#           TRTMLMA12903CCB956                                      My Way
#           TRQDDIF128F933AB89                        My Way (A Mi Manera)
#           TRYEPZK128F42A3425                                      My Way
#           TRDHEGR128F933E76D                                      My Way
#           TRHDXLP128EF3500FA                                      My Way
#           TROJGKW128F9309301                                      My Way
#           TRSQJMW128F93135CA                                      My Way
#           TROSEGE12903CC292F                                      My Way
#           TRDOZEB12903CF8B75                                      My Way
# 3268      TRCJMWH12903CB0D6A                      Can't Find My Way Home
#           TRTZPUX128F930F5CB                      Can't Find My Way Home
#           TRXIWCM128F92D2185                      Can't Find My Way Home
# 3651      TRZIQIE128F4271A5C                                 Love My Way
#           TRAFRJH128E0781C5B                                 Love My Way
#           TRIJOXI128F9354280                                 Love My Way
#           TROUXEQ128F428AF38                                 Love My Way
#           TRXHNET128F4245102                                 Love My Way
# 4905      TRFFLAQ128E0789DA3                           I'll Be On My Way
#           TRWQTNR128F427B62B                           I'll Be On My Way
# 5728      TRJLNHE128F426D6C3  If I Had My Way I'd Tear The Building Down
#
#                                  language                date         country  \
# clique_id trackID
# 360       TRIXWWI128F931A549  Unavailable                1969  United Kingdom
#           TRRDVDU128F9343523  Unavailable                2001   United States
# 893       TRLCKQT12903CFC1E8      English       December 2009          Sweden
#           TRXWMEY128F4289BC3      English    February 8, 1993   United States
#           TRFKFUN128F9327A53  Unavailable                 nan         Belgium
# 1190      TRIYKMR12903CC42A5      English                1970  United Kingdom
#           TRAGXNT12903CEB1B9      English                2002   United States
#           TRBTFYW128F92D4894      English       February 1973  United Kingdom
#           TRAOJAH12903CF7E6F      English     October 2, 2009          France
#           TROXIGK128F92C2597      English      March 12, 2007  United Kingdom
#           TRTMLMA12903CCB956      English  September 21, 2009   United States
#           TRQDDIF128F933AB89      Spanish    November 1, 2004  United Kingdom
#           TRYEPZK128F42A3425      English                2005  United Kingdom
#           TRDHEGR128F933E76D      English                1970   United States
#           TRHDXLP128EF3500FA      English       June 30, 1978  United Kingdom
#           TROJGKW128F9309301      English   November 19, 2008         Finland
#           TRSQJMW128F93135CA      English                1995   United States
#           TROSEGE12903CC292F      English                1998             NaN
#           TRDOZEB12903CF8B75      English     August 28, 2007          Canada
# 3268      TRCJMWH12903CB0D6A      English                1975  United Kingdom
#           TRTZPUX128F930F5CB      English            May 1989   United States
#           TRXIWCM128F92D2185      English                1972   United States
# 3651      TRZIQIE128F4271A5C      English           July 1982  United Kingdom
#           TRAFRJH128E0781C5B      English                1987  United Kingdom
#           TRIJOXI128F9354280      English   September 5, 2006   United States
#           TROUXEQ128F428AF38      English       June 23, 2008   United States
#           TRXHNET128F4245102      English                2001   United States
# 4905      TRFFLAQ128E0789DA3      English           June 2005  United Kingdom
#           TRWQTNR128F427B62B      English          April 1963  United Kingdom
# 5728      TRJLNHE128F426D6C3      English                1928   United States
#
#                                     genre  year  rank    status
# clique_id trackID
# 360       TRIXWWI128F931A549        Blues  1969     1  original
#           TRRDVDU128F9343523          NaN  2001     2     cover
# 893       TRLCKQT12903CFC1E8          NaN  2009     2     cover
#           TRXWMEY128F4289BC3         Rock  1993     1     cover
#           TRFKFUN128F9327A53        Dance   nan     3     cover
# 1190      TRIYKMR12903CC42A5          NaN  1970     1  original
#           TRAGXNT12903CEB1B9          NaN  2002     6     cover
#           TRBTFYW128F92D4894          NaN  1973     2     cover
#           TRAOJAH12903CF7E6F          NaN  2009    11     cover
#           TROXIGK128F92C2597    Classical  2007     9     cover
#           TRTMLMA12903CCB956          NaN  2009    11     cover
#           TRQDDIF128F933AB89    Classical  2004     7     cover
#           TRYEPZK128F42A3425          NaN  2005     8     cover
#           TRDHEGR128F933E76D          NaN  1970     1     cover
#           TRHDXLP128EF3500FA  Alternative  1978     3     cover
#           TROJGKW128F9309301         Rock  2008    10     cover
#           TRSQJMW128F93135CA          NaN  1995     4     cover
#           TROSEGE12903CC292F        Latin  1998     5     cover
#           TRDOZEB12903CF8B75        Dance  2007     9     cover
# 3268      TRCJMWH12903CB0D6A         Rock  1975     2     cover
#           TRTZPUX128F930F5CB  Alternative  1989     3     cover
#           TRXIWCM128F92D2185  Alternative  1972     1  original
# 3651      TRZIQIE128F4271A5C  Alternative  1982     1  original
#           TRAFRJH128E0781C5B   Electronic  1987     2     cover
#           TRIJOXI128F9354280          Pop  2006     4     cover
#           TROUXEQ128F428AF38  Alternative  2008     5     cover
#           TRXHNET128F4245102          NaN  2001     3     cover
# 4905      TRFFLAQ128E0789DA3       Reggae  2005     2     cover
#           TRWQTNR128F427B62B          Pop  1963     1  original
# 5728      TRJLNHE128F426D6C3        Blues  1928     1  original

# %%
# Clique for "My Way"
covers.loc[1190]
# Out:
#                               artistID shsPerf                      artist  \
# trackID
# TRIYKMR12903CC42A5  ARKLWV31187FB4881F  126517             Dorothy Squires
# TRAGXNT12903CEB1B9  AR7AOEJ1187FB3D279   82005               Little Milton
# TRBTFYW128F92D4894  ARJIAK51187B9B0C57  114545               Cliff Richard
# TRAOJAH12903CF7E6F  ARZH5GY1187B991039  106683               Dany Brillant
# TROXIGK128F92C2597  AR4Q56Q1187FB4BF63   51285                   Ray Quinn
# TRTMLMA12903CCB956  ARM900S1187FB5A3F7  103370             Micah P. Hinson
# TRQDDIF128F933AB89  ARNJ9LU1187B9A56A6  111710                     Il Divo
# TRYEPZK128F42A3425  ARL7YU61187B9B85D7  112544  G4 feat. Sir Cliff Richard
# TRDHEGR128F933E76D  ARFAKTH1187B9B0C18   42161   The Chairmen of the Board
# TRHDXLP128EF3500FA  ARD3LXU1187B9ABFC5    6467                 Sex Pistols
# TROJGKW128F9309301  ARV8WE01187FB4D356  149098              Northern Kings
# TRSQJMW128F93135CA  AR2ZLR21187B98D552   82027              Dread Zeppelin
# TROSEGE12903CC292F  ARY5U6T1187FB5AE47   18499                 Los Piratas
# TRDOZEB12903CF8B75  AR65T9K1187FB3842E   68888                   Paul Anka
#
#                                                     title language  \
# trackID
# TRIYKMR12903CC42A5                  My Way (Instrumental)  English
# TRAGXNT12903CEB1B9                                 My Way  English
# TRBTFYW128F92D4894  My Way (Live) (2008 Digital Remaster)  English
# TRAOJAH12903CF7E6F                                 My Way  English
# TROXIGK128F92C2597                                 My Way  English
# TRTMLMA12903CCB956                                 My Way  English
# TRQDDIF128F933AB89                   My Way (A Mi Manera)  Spanish
# TRYEPZK128F42A3425                                 My Way  English
# TRDHEGR128F933E76D                                 My Way  English
# TRHDXLP128EF3500FA                                 My Way  English
# TROJGKW128F9309301                                 My Way  English
# TRSQJMW128F93135CA                                 My Way  English
# TROSEGE12903CC292F                                 My Way  English
# TRDOZEB12903CF8B75                                 My Way  English
#
#                                   date         country        genre  year  \
# trackID
# TRIYKMR12903CC42A5                1970  United Kingdom          NaN  1970
# TRAGXNT12903CEB1B9                2002   United States          NaN  2002
# TRBTFYW128F92D4894       February 1973  United Kingdom          NaN  1973
# TRAOJAH12903CF7E6F     October 2, 2009          France          NaN  2009
# TROXIGK128F92C2597      March 12, 2007  United Kingdom    Classical  2007
# TRTMLMA12903CCB956  September 21, 2009   United States          NaN  2009
# TRQDDIF128F933AB89    November 1, 2004  United Kingdom    Classical  2004
# TRYEPZK128F42A3425                2005  United Kingdom          NaN  2005
# TRDHEGR128F933E76D                1970   United States          NaN  1970
# TRHDXLP128EF3500FA       June 30, 1978  United Kingdom  Alternative  1978
# TROJGKW128F9309301   November 19, 2008         Finland         Rock  2008
# TRSQJMW128F93135CA                1995   United States          NaN  1995
# TROSEGE12903CC292F                1998             NaN        Latin  1998
# TRDOZEB12903CF8B75     August 28, 2007          Canada        Dance  2007
#
#                     rank    status
# trackID
# TRIYKMR12903CC42A5     1  original
# TRAGXNT12903CEB1B9     6     cover
# TRBTFYW128F92D4894     2     cover
# TRAOJAH12903CF7E6F    11     cover
# TROXIGK128F92C2597     9     cover
# TRTMLMA12903CCB956    11     cover
# TRQDDIF128F933AB89     7     cover
# TRYEPZK128F42A3425     8     cover
# TRDHEGR128F933E76D     1     cover
# TRHDXLP128EF3500FA     3     cover
# TROJGKW128F9309301    10     cover
# TRSQJMW128F93135CA     4     cover
# TROSEGE12903CC292F     5     cover
# TRDOZEB12903CF8B75     9     cover

# %%
r=requests.get('https://secondhandsongs.com/work/4250/versions#nav-entity')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
len(soup.find_all('table'))
# Out:
# 27

# %%
soup.find_all('table')[0].find('tbody').find_all('tr')[15]
# Out:
# <tr itemprop="recordedAs" itemscope="" itemtype="http://schema.org/MusicRecording">
# <td class="field-icon"></td>
# <td class="field-title"><a class="link-performance" href="/performance/491567/versions" itemprop="url"><span itemprop="name">Comme d'habitude</span></a></td>
# <td class="field-performer"><span itemprop="byArtist" itemscope="" itemtype="http://schema.org/MusicGroup"><a class="link-performer" href="/artist/26302" itemprop="url"><span itemprop="name">M. Pokora</span></a></span></td>
# <td class="field-date">October 21, 2016</td>
# <td class="field-info"></td>
# </tr>

# %%
soup.find_all('table')[17].find('tbody').find_all('tr')[0].find('td',attrs={'class':'field-performer'}).find('a')['href'].split('/')[2]
# Out:
# '41140'

# %%
# Functions to search for each track "My Way" informations about its language, its released date and artist informations
def myWay_versions(table_id) :
    
    songs_table=[]
    nb_elems=len(soup.find_all('table')[table_id].find('tbody').find_all('tr')) 
    
    for i in range(0,nb_elems) : # Go through all the tracks contained in the table
        elem_sect=soup.find_all('table')[table_id].find('tbody').find_all('tr')[i]
        song_sect=elem_sect.find('td',attrs={'class':'field-title'})
        artist_sect=elem_sect.find('td',attrs={'class':'field-performer'})
        info_sect=elem_sect.find('td',attrs={'class':'field-info'})
        
        if info_sect.text=='Submitted' :
            status='case'
        else :
            status='performance'
    
        artist_id=artist_sect.find('a')
        
        if artist_id is None :
            artist_id='Missing'
        else :
            artist_id=artist_id['href'].split('/')[2]
            
            if artist_id.find('+')!=-1 : #For featuring (several artist_id) keep first one
                artist_id=int(artist_id.split('+')[0])
            else :
                artist_id=int(artist_id)
        
        artist_name=artist_sect.text
        song_id=int(song_sect.find('a')['href'].split('/')[2])
        song_name=song_sect.text
        perfLanguage, perfDate, artist_nationality = get_info(song_id,artist_id,status)
        songs_table.append([artist_name, song_name, perfLanguage, perfDate, artist_nationality])
    
    return songs_table
    
    
def get_info(song_id,artist_id,status) :     
# Web-scrapping of performance page (language and released year of the track)
    song_request = requests.get('https://secondhandsongs.com/'+status+'/'+str(song_id)) # Access to the song page on SHS

    song_soup = BeautifulSoup(song_request.text, 'html.parser')
    perfMeta=song_soup.find('dl',attrs={'class':'dl-horizontal'})

    if perfMeta is None :
        perfLanguage='Missing'
        perfDate='Missing'
    else :
        # Extract language
        perfLanguage=perfMeta.find('dd',attrs={'itemprop':'inLanguage'})
        if perfLanguage is None :
            
            if perfMeta.find_all('dd') is None :
                perfLanguage='Missing'
            else :
                perfLanguage1=perfMeta.find_all('dd')[3].text.replace(" ","").strip('\n').rstrip('\n')
                perfLanguage2=perfMeta.find_all('dd')[2].text.replace(" ","").strip('\n').rstrip('\n')
                
                if (perfLanguage1=='') & (perfLanguage2 !='') :
                    perfLanguage=perfLanguage2
                elif (perfLanguage2=='') & (perfLanguage1 !='') :
                    perfLanguage=perfLanguage1
                else :
                    perfLanguage='Missing'
                
            
        else :
            perfLanguage=perfLanguage.text

        # Extract released date    
        perfDate=perfMeta.find('div',attrs={'class':'media-body'})
        if perfDate is None :
            
            if perfMeta.find_all('dd') is None :
                perfDate='Missing'
            else :
                perfDate=perfMeta.find_all('dd')[6].text
            
        else :
            perfDate=perfDate.find('p').text.split('\n')[2].strip(' ')

# Web-scrapping of performance page (language and released year of the track)

    if artist_id=='Missing':
        artist_nationality='Missing'
    else :
        
        artist_request = requests.get('https://secondhandsongs.com/artist/'+str(artist_id)) # Access to the song page on SHS
        artist_soup = BeautifulSoup(artist_request.text, 'html.parser')
        artist_nationality=artist_soup.find('dl',attrs={'class':'dl-horizontal'}).find('dd',attrs={'itemprop':'nationality'})

        if artist_nationality is None :
            artist_nationality='Missing'
        else :
            artist_nationality=artist_nationality.text.split(' ')[-1].rstrip('\n')

    return perfLanguage, perfDate, artist_nationality

# %%
myWay=pd.DataFrame()

# %%
#for i in range(0,len(soup.find_all('table'))):
#    myWay=myWay.append(myWay_versions(i))

# %%
#pickle.dump(myWay,open('data/song_story.p','wb'))
myWay=pickle.load(open('data/song_story.p','rb'))

# %%
# Rename unvalid country (cut with algorithm)
myWay.replace(['Kingdom','States'],['United Kingdom','United States'],inplace=True)

# %%
# Rename columns
myWay.columns=['artist','title','language','date','location']
myWay.reset_index(drop=True,inplace=True)

# %%
myWay['year']=myWay.date.str[-4:]
myWay.drop('date',axis=1,inplace=True)

# %%
myWay.head()
# Out:
#              artist             title language location  year
# 0   Claude François  Comme d'habitude   French   France  1967
# 1   Michel Pagliaro  Comme d'habitude   French   Canada  1968
# 2     Michel Sardou  Comme d'habitude   French   France  1978
# 3      Hervé Vilard  Comme d'habitude   French   France  1984
# 4  Mireille Mathieu  Comme d'habitude   French   France  1985

# %%
print('Number of missing artists : ', len(myWay[myWay.artist=='Missing']))
print('Number of missing titles : ', len(myWay[myWay.title=='Missing']))
print('Number of missing languages : ', len(myWay[myWay.language=='Missing']))
print('Number of missing years : ', len(myWay[myWay.year=='Missing']))
print('Number of missing locations : ', len(myWay[myWay.location=='Missing']))
# Out:
# Number of missing artists :  0
# Number of missing titles :  0
# Number of missing languages :  1
# Number of missing years :  0
# Number of missing locations :  39

# %%
myWay[myWay.language=='Missing']
# Out:
#              artist   title language location  year
# 28  Takeshi Inomata  My Way  Missing    Japan  1975

# %%
myWay.loc[28, 'language'] = 'Instrumental'

# %%
#Remove weird covers
myWay.drop(157,axis=0,inplace=True)

# %%
#Remove [1] in artist names
myWay.replace('[1]','',inplace=True)

# %%
myWay.loc[[5,180],'location'] = 'Italy'
myWay.loc[[9,236],'location'] = 'Switzerland'
myWay.loc[[11],'location'] = 'Belgium'
myWay.loc[[25,57,145,153],'location'] = 'United Kingdom'
myWay.loc[[40,277],'location'] = 'France'
myWay.loc[[60],'location'] = 'Poland'
myWay.loc[[70],'location'] = 'Canada'
myWay.loc[[72,188,221,250,278],'location'] = 'United States'
myWay.loc[[72],'artist'] = 'Francky Perez'
myWay.loc[[115,247],'location'] ='Czech Republic'
myWay.loc[[156],'location'] ='Serbia'
myWay.loc[[156],'artist']='Boba Stefanović'
myWay.loc[[174,248],'location'] ='Spain'
myWay.loc[[191],'location'] ='Brazil'
myWay.loc[[208],'location'] ='Australia'
myWay.loc[[218],'location'] ='Hungary'
myWay.loc[[265,270,286],'location'] ='Germany'
myWay.loc[[275],'location'] ='Russia'
myWay.loc[[288],'location'] ='Austria'

# %%
myWay.drop(myWay[myWay.location=='Missing'].index,axis=0,inplace=True)

# %%
myWay[myWay.location=='Missing']
# Out:
# Empty DataFrame
# Columns: [artist, title, language, location, year]
# Index: []

# %%
myWay
# Out:
#                                         artist                      title  \
# 0                              Claude François           Comme d'habitude
# 1                              Michel Pagliaro           Comme d'habitude
# 2                                Michel Sardou           Comme d'habitude
# 3                                 Hervé Vilard           Comme d'habitude
# 4                             Mireille Mathieu           Comme d'habitude
# 5                             Ruggero Raimondi           Comme d'habitude
# 6                                Florent Pagny           Comme d'habitude
# 7                              Richard Anthony           Comme d'habitude
# 8                              Herbert Léonard           Comme d'habitude
# 9                                       Gunvor           Comme d'habitude
# 10                               Elli Medeiros           Comme d'habitude
# 11                        Eddy et les vedettes           Comme d'habitude
# 12                              Tale of Voices           Comme d'habitude
# 14                        Liliane Saint-Pierre           Comme d'habitude
# 15                                   M. Pokora           Comme d'habitude
# 16                                Charlie Byrd                     My Way
# 17                                 Chet Atkins                     My Way
# 18   Bill Watrous with The Walter Raim Concept                     My Way
# 19                          Ferrante & Teicher                     My Way
# 20                 Mantovani and His Orchestra                     My Way
# 21                                  Peter Nero                     My Way
# 22                  The StereoAction Orchestra                     My Way
# 23                                 Gene Ammons                     My Way
# 24                         The Don Reeve Sound  My Way (Comme d'habitude)
# 25                                  Phil Allen                     My Way
# 26            Bert Kaempfert and His Orchestra                     My Way
# 28                             Takeshi Inomata                     My Way
# 29      Jean-Claude Pelletier et son orchestre                     My Way
# 30                              Claude Denjean                     My Way
# 31                    Franck Pourcel Orchestra                     My Way
# ..                                         ...                        ...
# 259                             Rudi Schuricke         So leb' dein Leben
# 260                               Peter Orloff          So leb dein Leben
# 261                                     Belina          So leb dein Leben
# 262                           Mireille Mathieu          So leb dein Leben
# 263                             Nana Mouskouri          So leb dein Leben
# 264                                Mark Lorenz          So leb dein Leben
# 265      Tony Marshall Featuring Xavier Naidoo          So leb Dein Leben
# 266                                 Nina Hagen                     My Way
# 267                            Claude François                Come sempre
# 268                              Fred Bongusto                 La mia via
# 269                                Patty Pravo                 A modo mio
# 270                           Vanessa Calcagno     La mia strada (My Way)
# 271                             Andrea Bocelli        La mia via (My Way)
# 272                                 Akira Fuse            マイ・ウェイ [My Way]
# 273                                      Saeko                     My Way
# 274                            Agnaldo Timóteo          Eu já me habituei
# 275                          Звезды Notre Dame                   Мой путь
# 276                                    La Lupe           Como acostumbras
# 277                                Gipsy Kings                A mi manera
# 278                                  Joan Baez                A mi manera
# 279                                Belle Perez                A mi manera
# 280                                    Il Divo                A mi manera
# 281                                      Alfio       A mi manera (My Way)
# 282                                 Paul Potts       My Way (A mi manera)
# 283                      Raphael con Paul Anka                A mi manera
# 284                             Los Temerarios                A mi manera
# 285                                Dafydd Iwan                Dal i Gredu
# 286                              Harald Juhnke                     My Way
# 287                       Zangeres Zonder Naam        Mijn leven (My Way)
# 288                            Joesi Prokopetz                  My Schmäh
#
#          language        location  year
# 0          French          France  1967
# 1          French          Canada  1968
# 2          French          France  1978
# 3          French          France  1984
# 4          French          France  1985
# 5          French           Italy  1988
# 6          French          France  1989
# 7          French          France  1996
# 8          French          France  1998
# 9         English     Switzerland  1970
# 10         French         Uruguay  2008
# 11         French         Belgium  2010
# 12         French          France  2012
# 14         French         Belgium  2014
# 15         French          France  2016
# 16   Instrumental   United States  1969
# 17   Instrumental   United States  1969
# 18   Instrumental   United States  1969
# 19   Instrumental   United States  1969
# 20   Instrumental  United Kingdom  1970
# 21   Instrumental   United States  1970
# 22   Instrumental  United Kingdom  1971
# 23   Instrumental   United States  1971
# 24   Instrumental  United Kingdom  1971
# 25   Instrumental  United Kingdom  1971
# 26   Instrumental         Germany  1972
# 28   Instrumental           Japan  1975
# 29   Instrumental          France  1976
# 30   Instrumental          France  1977
# 31   Instrumental          France  1978
# ..            ...             ...   ...
# 259        German         Germany  1973
# 260        German         Germany  1978
# 261        German          Poland  1981
# 262        German          France  1985
# 263        German          Greece  1991
# 264        German         Germany  2001
# 265       English         Germany  1996
# 266        German         Germany  1980
# 267       Italian          France  1968
# 268       Italian           Italy  1971
# 269       Italian           Italy  1972
# 270       Italian         Germany  2010
# 271       Italian           Italy  2013
# 272      Japanese           Japan  1972
# 273      Japanese           Japan  2006
# 274    Portuguese          Brazil  1969
# 275       Russian          Russia  2003
# 276       Spanish            Cuba  1970
# 277       Spanish          France  1987
# 278       Spanish   United States  1989
# 279       English         Belgium  1973
# 280       Spanish  United Kingdom  2004
# 281       Spanish       Australia  2006
# 282       Spanish  United Kingdom  2007
# 283       Spanish          Canada  2008
# 284       Spanish          Mexico  2012
# 285         Welsh  United Kingdom  1991
# 286       English         Germany  1996
# 287       English     Netherlands  1992
# 288       English         Austria  2001
#
# [281 rows x 5 columns]

# %%
pickle.dump(myWay,open('data/song_story.p','wb'))
#myWay=pickle.load(open('data/song_story.p','rb'))
