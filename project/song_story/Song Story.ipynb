# %% [markdown]
# # Project story
# ### Follow the evolution of "My way"
#
# #### Plan
# - 14 covers in our dataset and 289 on SHS website
# - Web-scrapping of the covers we don't have
# - Have at least Country/Year/Language/Artist/Title for each song

# %%
# Import libraries
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from io import StringIO
import sys
import requests
from bs4 import BeautifulSoup
import pickle
import os
import glob
from pathlib import Path

# %%
#Load covers dataframe
covers=pickle.load(open("covers_FINAL.p","rb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-66db3f115976> in <module>()
#       1 #Load covers dataframe
# ----> 2 covers=pickle.load(open("covers_FINAL.p","rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'covers_FINAL.p'

# %%
#Clique of "My way"
covers[covers.title.str.contains('My Way')]

# %%
# Clique for "My Way"
covers.loc[1190]

# %%
r=requests.get('https://secondhandsongs.com/work/4250/versions#nav-entity')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
len(soup.find_all('table'))

# %%
soup.find_all('table')[0].find('tbody').find_all('tr')[15]

# %%
soup.find_all('table')[17].find('tbody').find_all('tr')[0].find('td',attrs={'class':'field-performer'}).find('a')['href'].split('/')[2]

# %%
# Functions to search for each track "My Way" informations about its language, its released date and artist informations
def myWay_versions(table_id) :
    
    songs_table=[]
    nb_elems=len(soup.find_all('table')[table_id].find('tbody').find_all('tr')) 
    
    for i in range(0,nb_elems) : # Go through all the tracks contained in the table
        elem_sect=soup.find_all('table')[table_id].find('tbody').find_all('tr')[i]
        song_sect=elem_sect.find('td',attrs={'class':'field-title'})
        artist_sect=elem_sect.find('td',attrs={'class':'field-performer'})
        info_sect=elem_sect.find('td',attrs={'class':'field-info'})
        
        if info_sect.text=='Submitted' :
            status='case'
        else :
            status='performance'
    
        artist_id=artist_sect.find('a')
        
        if artist_id is None :
            artist_id='Missing'
        else :
            artist_id=artist_id['href'].split('/')[2]
            
            if artist_id.find('+')!=-1 : #For featuring (several artist_id) keep first one
                artist_id=int(artist_id.split('+')[0])
            else :
                artist_id=int(artist_id)
        
        artist_name=artist_sect.text
        song_id=int(song_sect.find('a')['href'].split('/')[2])
        song_name=song_sect.text
        perfLanguage, perfDate, artist_nationality = get_info(song_id,artist_id,status)
        songs_table.append([artist_name, song_name, perfLanguage, perfDate, artist_nationality])
    
    return songs_table
    
    
def get_info(song_id,artist_id,status) :     
# Web-scrapping of performance page (language and released year of the track)
    song_request = requests.get('https://secondhandsongs.com/'+status+'/'+str(song_id)) # Access to the song page on SHS

    song_soup = BeautifulSoup(song_request.text, 'html.parser')
    perfMeta=song_soup.find('dl',attrs={'class':'dl-horizontal'})

    if perfMeta is None :
        perfLanguage='Missing'
        perfDate='Missing'
    else :
        # Extract language
        perfLanguage=perfMeta.find('dd',attrs={'itemprop':'inLanguage'})
        if perfLanguage is None :
            
            if perfMeta.find_all('dd') is None :
                perfLanguage='Missing'
            else :
                perfLanguage1=perfMeta.find_all('dd')[3].text.replace(" ","").strip('\n').rstrip('\n')
                perfLanguage2=perfMeta.find_all('dd')[2].text.replace(" ","").strip('\n').rstrip('\n')
                
                if (perfLanguage1=='') & (perfLanguage2 !='') :
                    perfLanguage=perfLanguage2
                elif (perfLanguage2=='') & (perfLanguage1 !='') :
                    perfLanguage=perfLanguage1
                else :
                    perfLanguage='Missing'
                
            
        else :
            perfLanguage=perfLanguage.text

        # Extract released date    
        perfDate=perfMeta.find('div',attrs={'class':'media-body'})
        if perfDate is None :
            
            if perfMeta.find_all('dd') is None :
                perfDate='Missing'
            else :
                perfDate=perfMeta.find_all('dd')[6].text
            
        else :
            perfDate=perfDate.find('p').text.split('\n')[2].strip(' ')

# Web-scrapping of performance page (language and released year of the track)

    if artist_id=='Missing':
        artist_nationality='Missing'
    else :
        
        artist_request = requests.get('https://secondhandsongs.com/artist/'+str(artist_id)) # Access to the song page on SHS
        artist_soup = BeautifulSoup(artist_request.text, 'html.parser')
        artist_nationality=artist_soup.find('dl',attrs={'class':'dl-horizontal'}).find('dd',attrs={'itemprop':'nationality'})

        if artist_nationality is None :
            artist_nationality='Missing'
        else :
            artist_nationality=artist_nationality.text.split(' ')[-1].rstrip('\n')

    return perfLanguage, perfDate, artist_nationality

# %%
myWay=pd.DataFrame()

# %%
#for i in range(0,len(soup.find_all('table'))):
#    myWay=myWay.append(myWay_versions(i))

# %%
#pickle.dump(myWay,open('data/song_story.p','wb'))
myWay=pickle.load(open('song_story.p','rb'))

# %%
# Rename unvalid country (cut with algorithm)
myWay.replace(['Kingdom','States'],['United Kingdom','United States'],inplace=True)

# %%
# Rename columns
myWay.columns=['artist','title','language','date','location']
myWay.reset_index(drop=True,inplace=True)

# %%
myWay['year']=myWay.date.str[-4:]
myWay.drop('date',axis=1,inplace=True)

# %%
myWay.head()
# Out:
#              artist             title language location  year
# 0   Claude François  Comme d'habitude   French     1967  ance
# 1   Michel Pagliaro  Comme d'habitude   French     1968  nada
# 2     Michel Sardou  Comme d'habitude   French     1978  ance
# 3      Hervé Vilard  Comme d'habitude   French     1984  ance
# 4  Mireille Mathieu  Comme d'habitude   French     1985  ance

# %%
print('Number of missing artists : ', len(myWay[myWay.artist=='Missing']))
print('Number of missing titles : ', len(myWay[myWay.title=='Missing']))
print('Number of missing languages : ', len(myWay[myWay.language=='Missing']))
print('Number of missing years : ', len(myWay[myWay.year=='Missing']))
print('Number of missing locations : ', len(myWay[myWay.location=='Missing']))
# Out:
# Number of missing artists :  0
# Number of missing titles :  0
# Number of missing languages :  0
# Number of missing years :  0
# Number of missing locations :  0

# %%
myWay[myWay.language=='Missing']
# Out:
# Empty DataFrame
# Columns: [artist, title, language, location, year]
# Index: []

# %%
myWay.loc[28, 'language'] = 'Instrumental'

# %%
#Remove weird covers
myWay.drop(157,axis=0,inplace=True)

# %%
#Remove [1] in artist names
myWay.replace('[1]','',inplace=True)

# %%
myWay.loc[[5,180],'location'] = 'Italy'
myWay.loc[[9,236],'location'] = 'Switzerland'
myWay.loc[[11],'location'] = 'Belgium'
myWay.loc[[25,57,145,153],'location'] = 'United Kingdom'
myWay.loc[[40,277],'location'] = 'France'
myWay.loc[[60],'location'] = 'Poland'
myWay.loc[[70],'location'] = 'Canada'
myWay.loc[[72,188,221,250,278],'location'] = 'United States'
myWay.loc[[72],'artist'] = 'Francky Perez'
myWay.loc[[115,247],'location'] ='Czech Republic'
myWay.loc[[156],'location'] ='Serbia'
myWay.loc[[156],'artist']='Boba Stefanović'
myWay.loc[[174,248],'location'] ='Spain'
myWay.loc[[191],'location'] ='Brazil'
myWay.loc[[208],'location'] ='Australia'
myWay.loc[[218],'location'] ='Hungary'
myWay.loc[[265,270,286],'location'] ='Germany'
myWay.loc[[275],'location'] ='Russia'
myWay.loc[[288],'location'] ='Austria'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-70d30b2246ca> in <module>()
#      15 myWay.loc[[208],'location'] ='Australia'
#      16 myWay.loc[[218],'location'] ='Hungary'
# ---> 17 myWay.loc[[265,270,286],'location'] ='Germany'
#      18 myWay.loc[[275],'location'] ='Russia'
#      19 myWay.loc[[288],'location'] ='Austria'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     176         else:
#     177             key = com._apply_if_callable(key, self.obj)
# --> 178         indexer = self._get_setitem_indexer(key)
#     179         self._setitem_with_indexer(indexer, value)
#     180
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     155         if isinstance(key, tuple):
#     156             try:
# --> 157                 return self._convert_tuple(key, is_setter=True)
#     158             except IndexingError:
#     159                 pass
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     222                 if i >= self.obj.ndim:
#     223                     raise IndexingError('Too many indexers')
# --> 224                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     225                 keyidx.append(idx)
#     226         return tuple(keyidx)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: '[286] not in index'

# %%
myWay.drop(myWay[myWay.location=='Missing'].index,axis=0,inplace=True)

# %%
myWay[myWay.location=='Missing']
# Out:
# Empty DataFrame
# Columns: [artist, title, language, location, year]
# Index: []

# %%
myWay.sort_values('year')
# Out:
#                                         artist                title  \
# 0                              Claude François     Comme d'habitude
# 1                              Michel Pagliaro     Comme d'habitude
# 267                            Claude François          Come sempre
# 90                               John Davidson               My Way
# 89                                The Platters               My Way
# 88                                 Bill Medley               My Way
# 87                               Andy Williams               My Way
# 86                           Lore'z Alexandria               My Way
# 85                                 Eddy Arnold               My Way
# 84                                  Roy Drusky               My Way
# 83                                   Paul Anka               My Way
# 82                      The Anita Kerr Singers               My Way
# 81                                  Jerry Vale               My Way
# 80                             Top of the Pops               My Way
# 79                               Frank Sinatra               My Way
# 91                              Steve Lawrence               My Way
# 18   Bill Watrous with The Walter Raim Concept               My Way
# 19                          Ferrante & Teicher               My Way
# 16                                Charlie Byrd               My Way
# 92                               George Wright               My Way
# 93                             Hugo Montenegro               My Way
# 94                                   Joe Dolan               My Way
# 17                                 Chet Atkins               My Way
# 274                            Agnaldo Timóteo    Eu já me habituei
# 110                                 Al Martino               My Way
# 109                      Chairmen of the Board               My Way
# 108                                 John Raitt               My Way
# 107                                 Matt Monro               My Way
# 106                                  Vera Lynn               My Way
# 103                            Sammy Davis Jr.               My Way
# ..                                         ...                  ...
# 223                               Josh Dubovie               My Way
# 224                               Patti Austin               My Way
# 225                            Daniel Küblböck               My Way
# 226                                Birthe Kjær               My Way
# 227                  Landau Eugene Murphy, Jr.               My Way
# 228                                 Wade Tower               My Way
# 284                             Los Temerarios          A mi manera
# 229                                 Chris Mann               My Way
# 230                                  Tom Evers               My Way
# 231             Ricky Norton with James Burton               My Way
# 12                              Tale of Voices     Comme d'habitude
# 234                            Tri Tenor Cymru               My Way
# 271                             Andrea Bocelli  La mia via (My Way)
# 232                          Paul Anka - Garou               My Way
# 235                           The Texas Tenors               My Way
# 233                                   Sol3 Mio               My Way
# 76                             André Hazes jr.               Waarom
# 14                        Liliane Saint-Pierre     Comme d'habitude
# 237                          Daniel Boaventura               My Way
# 238                 Roger Cicero mit Paul Anka               My Way
# 240            Jazzkören med Goodmankvartetten               My Way
# 241              Ricky Norton & Candice Parise               My Way
# 239                               Roger Cicero               My Way
# 242                   Rio - The Voice of Elvis               My Way
# 243                                    Il Volo               My Way
# 244                           Ben L'Oncle Soul               My Way
# 245                              Jim Armstrong               My Way
# 246                            Seth MacFarlane               My Way
# 256                                Masa Mainds          Minun tieni
# 15                                   M. Pokora     Comme d'habitude
#
#          language        location  year
# 0          French          France  1967
# 1          French          Canada  1968
# 267       Italian          France  1968
# 90        English   United States  1969
# 89        English   United States  1969
# 88        English   United States  1969
# 87        English   United States  1969
# 86        English   United States  1969
# 85        English   United States  1969
# 84        English   United States  1969
# 83        English          Canada  1969
# 82        English   United States  1969
# 81        English   United States  1969
# 80        English  United Kingdom  1969
# 79        English   United States  1969
# 91        English   United States  1969
# 18   Instrumental   United States  1969
# 19   Instrumental   United States  1969
# 16   Instrumental   United States  1969
# 92        English   United States  1969
# 93        English   United States  1969
# 94        English         Ireland  1969
# 17   Instrumental   United States  1969
# 274    Portuguese          Brazil  1969
# 110       English   United States  1970
# 109       English   United States  1970
# 108       English   United States  1970
# 107       English  United Kingdom  1970
# 106       English  United Kingdom  1970
# 103       English   United States  1970
# ..            ...             ...   ...
# 223       English  United Kingdom  2011
# 224       English   United States  2011
# 225       English         Germany  2011
# 226       English         Denmark  2011
# 227       English   United States  2011
# 228       English   United States  2011
# 284       Spanish          Mexico  2012
# 229       English   United States  2012
# 230       English          France  2012
# 231       English   United States  2012
# 12         French          France  2012
# 234       English  United Kingdom  2013
# 271       Italian           Italy  2013
# 232       English          Canada  2013
# 235       English   United States  2013
# 233       English         Zealand  2013
# 76          Dutch     Netherlands  2014
# 14         French         Belgium  2014
# 237       English          Brazil  2014
# 238       English          Canada  2015
# 240       English          Sweden  2015
# 241       English          France  2015
# 239       English         Germany  2015
# 242       English         Germany  2016
# 243       English           Italy  2016
# 244       English          France  2016
# 245       English  United Kingdom  2016
# 246       English   United States  2016
# 256       Finnish         Finland  2016
# 15         French          France  2016
#
# [281 rows x 5 columns]

# %%
pickle.dump(myWay,open('data/song_story.p','wb'))
#myWay=pickle.load(open('data/song_story.p','rb'))

# %%
myWay[['title','year']].groupby('year').agg('count')
# Out:
#       title
# year
# 1967      1
# 1968      2
# 1969     21
# 1970     20
# 1971     15
# 1972      6
# 1973      7
# 1974      4
# 1975      7
# 1976      3
# 1977      2
# 1978     10
# 1979      6
# 1980      6
# 1981      3
# 1982      4
# 1983      2
# 1984      2
# 1985      6
# 1986      2
# 1987      4
# 1988      3
# 1989      2
# 1990      1
# 1991      3
# 1992      5
# 1993      3
# 1994      2
# 1995      2
# 1996      8
# 1997      2
# 1998     10
# 1999      4
# 2000      3
# 2001      8
# 2002      5
# 2003      6
# 2004      6
# 2005      5
# 2006     11
# 2007      8
# 2008      6
# 2009     10
# 2010      5
# 2011      6
# 2012      5
# 2013      5
# 2014      3
# 2015      4
# 2016      7
