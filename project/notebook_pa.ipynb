# %%
import pickle
import numpy
import pandas as pd
import os
import glob
from pathlib import Path
import numpy as np

# %% [markdown]
# We open the first file of the subset, to check what the HDF5 keys are and then we read each of them.

# %%
with pd.HDFStore("data/MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5") as hdf:
    print(hdf.keys())
# Out:
# ['/analysis/songs', '/metadata/songs', '/musicbrainz/songs']

# %%
pd.read_hdf("data/MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5","/analysis/songs")
# Out:
#    analysis_sample_rate                         audio_md5  danceability  \
# 0                 22050  a222795e07cd65b7a530f1346f520649           0.0
#
#     duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 0  218.93179           0.247     0.0                    0               0
#
#    idx_beats_confidence  idx_beats_start         ...          key  \
# 0                     0                0         ...            1
#
#    key_confidence  loudness  mode  mode_confidence  start_of_fade_out   tempo  \
# 0           0.736   -11.197     0            0.636            218.932  92.198
#
#    time_signature  time_signature_confidence            track_id
# 0               4                      0.778  TRAAAAW128F429D538
#
# [1 rows x 31 columns]

# %%
pd.read_hdf("data/MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5","/metadata/songs")
# Out:
#   analyzer_version  artist_7digitalid  artist_familiarity  artist_hotttnesss  \
# 0                              165270            0.581794           0.401998
#
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#                             artist_mbid artist_name  artist_playmeid genre  \
# 0  e77e51a5-4761-45b3-9847-2051f811e366      Casual             4479
#
#    idx_artist_terms  idx_similar_artists      release  release_7digitalid  \
# 0                 0                    0  Fear Itself              300848
#
#    song_hotttnesss             song_id             title  track_7digitalid
# 0          0.60212  SOMZWCG12A8C13C480  I Didn't Mean To           3401791

# %%
pd.read_hdf("data/MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5","/musicbrainz/songs")
# Out:
#    idx_artist_mbtags  year
# 0                  0     0

# %% [markdown]
# We only need to extract <tt>tempo</tt> and <tt>song_hotttnesss</tt>, here is an example of how to do that on the subset :

# %%
tempo = []
hotness = []

files = glob.glob("data/MillionSongSubset/data/A" + "/[A-Z]/[A-Z]/*")
for f in files:
    tempo.append(pd.read_hdf(f,"/analysis/songs")["tempo"][0])
    hotness.append(pd.read_hdf(f,"/metadata/songs")["song_hotttnesss"][0])

# %%
tempo = np.asarray(tempo)
hotness = np.asarray(hotness)
print(tempo)
print(hotness)
# Out:
# [ 124.059   80.084   54.874 ...,   96.064  149.012  162.653]
# [ 0.54795294  0.47563847         nan ...,         nan         nan  0.270776  ]

# %%
print("Number of tracks =", len(files))
print("with missing hotness values =", np.sum(np.isnan(hotness)))
# Out:
# Number of files = 7620
# with missing hotness values = 3268

# %% [markdown]
# We already got 3268 unknown hotness values and we only tested on a subset of 7620 song, so we can expect to have that information for only a little over half of our final dataset. Maybe we won't use it.

# %%
#loading of the dataframe YOU CAN REMOVE THAT IN THE FINAL NOTEBOOK
covers = pickle.load(open("data/covers.p","rb"))
covers
# Out:
#                   trackID            artistID  shsPerf  clique_id  \
# 0      TRGDMZP128F42BC52B  ARB1DDF1187FB4FCFB       -1          0
# 1      TRCATYW12903D038FE  ARGJEEO1271F573FD6       -1          0
# 18179  TRCGGYF128F9338B93  ARYDZKJ1187FB540C6    99680       5847
# 18180  TRAHFYD128F426BBAD  AR94ZOI1187FB46BDA   103980       5848
# 18181  TRRUFPY128F4261744  ARJWDFW1241B9C69AE   118487       5848
# 18182  TRTFWRF128F92E378E  ARX1CYE1187FB3A97B    99730       5849
# 18183  TRBXSHQ128F4278320  ARLM6I41187B9BA123    99731       5849
# 18184  TRGOMBU128F42895B9  AR14CJ91187FB3A994    99733       5849
# 18185  TRMCRMX128F4267AC3  ARSPUHE1187B99DB8A   125607       5850
# 18186  TRNBSWN128F1473B31  ARLG9UJ1187B9B6C67    24567       5850
# 18187  TRWAULS128F1474CBF  AR7GM0K1187B9B74B4    20304       5851
# 18188  TRZVRJL128F92E2984  ARDYR3C1187FB461CE     9982       5851
# 18189  TRMQPSQ128F426C548  ARAWPR61187B9B5A4C       -1       5851
# 18190  TRSDUWY128F92DD39A  ARR176H1187FB4CDFE    99838       5852
# 18191  TRUZAVE128F426E391  AR3DLBB1187B98F3DF   106651       5852
# 18192  TRDNIRY128F425A5C8  ARDRJSP126E2B3BEF8       -1       5852
# 18193  TRPVDKP128F934956E  ARELPXQ1187FB384FD   138704       5852
# 18194  TREMVLC128F92EFA95  ARBFDJW1187B9AD27A    29576       5853
# 18195  TRMTMWV128F92F6F78  ARDYR3C1187FB461CE     9986       5853
#
#                                        name  \
# 0                           Louis Armstrong
# 1              Artie Shaw and his orchestra
# 2                          Hoagy Carmichael
# 3      Connee Boswell & Sy Oliver Orchestra
# 4                                 Ana Belén
# 5                                 Fito Paez
# 6                  Electric Light Orchestra
# 7                                Lily Allen
# 8                                     Liars
# 9                           Yeah Yeah Yeahs
# 10                   Andrea True Connection
# 11                               Bananarama
# 12                              David Bowie
# 13                            Zen Guerrilla
# 14                                 Hear'Say
# 15                    The Mamas & The Papas
# 16                            Silicon Teens
# 17                              Chuck Berry
# 18     The Soggy Bottom Boys / Dan Tyminski
# 19                            Ralph Stanley
# 20                                     Korn
# 21                                      JFA
# 22                                      War
# 23                             Jeff Buckley
# 24                             Jamie Cullum
# 25                            Leonard Cohen
# 26                            Ian McCulloch
# 27                 Gladys Knight & The Pips
# 28                            Barbara Mason
# 29                                  The Who
# ...                                     ...
# 18166                               Di-rect
# 18167                            Count Five
# 18168                             Green Day
# 18169                       Joaquin Phoenix
# 18170                     Willie Heath Neal
# 18171       Tom Petty And The Heartbreakers
# 18172         Matthew Sweet & Susanna Hoffs
# 18173                              Big Star
# 18174                       The Loud Family
# 18175                          Gin Blossoms
# 18176                          Afghan Whigs
# 18177                  Sounds Like Violence
# 18178                          Afghan Whigs
# 18179                       Marshall_ Susan
# 18180                          Willie Dixon
# 18181              Todd Wolfe Blues Project
# 18182                         Bill Anderson
# 18183                             Roy Clark
# 18184                           Eddy Arnold
# 18185          Frank Marino & Mahogany Rush
# 18186             Charles River Valley Boys
# 18187                     The J. Geils Band
# 18188   George Thorogood And The Destroyers
# 18189                      The Strangeloves
# 18190                 Edwin Hawkins Singers
# 18191                  The Statler Brothers
# 18192                         Spiritualized
# 18193                         Queen Latifah
# 18194             The Fabulous Thunderbirds
# 18195   George Thorogood And The Destroyers
#
#                                       title    year
# 0                                  Stardust  1988.0
# 1                                  Stardust  1988.0
# 2                                 Star Dust  1999.0
# 3                                 Star Dust     NaN
# 4             Yo Vengo A Ofrecer Mi Corazon  2001.0
# 5             Yo Vengo A Ofrecer Mi Corazon     NaN
# 6                              Mr. Blue Sky  1977.0
# 7                               Mr Blue Sky  2007.0
# 8                        Mr Your On Fire Mr  2002.0
# 9                    Mr. You're On Fire Mr.  2003.0
# 10                           More More More  1991.0
# 11                         More_ More_ More  2001.0
# 12                  Moonage Daydream (Live)  1996.0
# 13                         Moonage Daydream     NaN
# 14                            Monday Monday     NaN
# 15                           Monday_ Monday     NaN
# 16                        Memphis Tennessee  1980.0
# 17                       Memphis_ Tennessee  1993.0
# 18            I Am A Man Of Constant Sorrow  2002.0
# 19                   Man Of Constant Sorrow  2002.0
# 20                                 Lowrider  1996.0
# 21                                 Lowrider  2003.0
# 22                                Low Rider     NaN
# 23           Lover_ You Should've Come Over     NaN
# 24         Lover_ You Should Have Come Over     NaN
# 25                        Lover Lover Lover  1974.0
# 26                      Lover_ Lover_ Lover     NaN
# 27                            Yes I'm Ready  1967.0
# 28                            Yes I'm Ready  1993.0
# 29                       Love Reign O'er Me  1983.0
# ...                                     ...     ...
# 18166                         My Generation  2001.0
# 18167                         My Generation  2003.0
# 18168         My Generation (Album version)     NaN
# 18169                         Cocaine Blues  2005.0
# 18170                         Cocaine Blues     NaN
# 18171                    Here Comes My Girl  1979.0
# 18172                    Here Comes My Girl  2009.0
# 18173                         Back Of A Car  1974.0
# 18174                         Back of a Car  1993.0
# 18175                         Back Of A Car  2002.0
# 18176                         Sammy (Album)  1990.0
# 18177                                 Sammy  2009.0
# 18178                         Going To Town  1996.0
# 18179                         Going To Town  2009.0
# 18180                        The Same Thing  1970.0
# 18181                            Same Thing     NaN
# 18182                 The Tip Of My Fingers  2002.0
# 18183                 The Tip Of My Fingers     NaN
# 18184                 The Tip of My Fingers     NaN
# 18185  Norwegian Wood (This Bird Has Flown)     NaN
# 18186           Norwegian Wood (LP Version)     NaN
# 18187                            Night Time  1980.0
# 18188                            Night Time     NaN
# 18189                            Night-Time     NaN
# 18190                          Oh Happy Day  1969.0
# 18191                          Oh Happy Day  1993.0
# 18192                          Oh Happy Day  1998.0
# 18193                          Oh Happy Day     NaN
# 18194                             Tip On In  1987.0
# 18195                             Tip On In     NaN
#
# [18196 rows x 7 columns]

# %% [markdown]
# Once all the files are accessible on the cluster, we will have to go through our SHS dataset and get those attributes for each track_id.
# We will do so in the following way : (the paths are just examples on the subset)

# %%
tempo = []
hotness = []

my_file = Path("/path/to/file")
for track in covers["trackID"]:
    folder1 = track[2]
    folder2 = track[3]
    folder3 = track[4]
    folder_path = "data/MillionSongSubset/data/" + folder1 + "/" + folder2 + "/" + folder3 + "/"
    track_path = folder_path + track + ".h5"
    if Path(track_path).exists(): #to delete later
        tempo.append(pd.read_hdf(track_path,"/analysis/songs")["tempo"][0])
        hotness.append(pd.read_hdf(track_path,"/metadata/songs")["song_hotttnesss"][0])

# %%
print(len(tempo))
print(np.sum(~np.isnan(hotness)))
# Out:
# 204
# 128

# %% [markdown]
# Unsurprisingly, we only found 204 of those tracks in the subset and 128 of them have a hotness value.
